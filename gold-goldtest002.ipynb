# %% [markdown]
# Simulation of head-to-head gold-gold ions collisions at 13 TeV
# ---

# %% [markdown]
#   |    Ali Bavarchee   |
# ---
# =-=-=-=-=-=-=-=

# %%
# Imports
import ROOT
# Out:
# Welcome to JupyROOT 6.26/10

# %%
import pythia8

# %%
# Pythia setup
pythia = pythia8.Pythia()

pythia.readString("HardQCD:all = on")  # Enable hard QCD processes to study jets
pythia.readString("Beams:eCM = 13000.")

pythia.readString("Beams:idA = 197; Beams:idB = 197")  # Au ions

#pythia.readString("ParticleDecays:limitTau0 = on")  # Decay all unstable particles
pythia.readString("Tune:pp = 2")  # Monash tune for pp collisions (adapt for Au+Au)
pythia.init()

# Event loop
events = 100  # Number of events
file = ROOT.TFile("alice_tree_4.root", "RECREATE")  # Create a ROOT file
tree = ROOT.TTree("alice_tree_4", "ALICE_Au+Au4_collisions_13_TeV")

# Create vectors for particle properties
px, py, pz, pt, eta, phi, pid = ROOT.std.vector("double")(), ROOT.std.vector("double")(), ROOT.std.vector("double")(), ROOT.std.vector("double")(), ROOT.std.vector("double")(), ROOT.std.vector("double")(), ROOT.std.vector("int")()

# Create branches by linking them with the vectors
tree.Branch("px", px)
tree.Branch("py", py)
tree.Branch("pz", pz)
tree.Branch("pt", pt)
tree.Branch("eta", eta)
tree.Branch("phi", phi)
tree.Branch("pid", pid)

for i in range(events):
    if not pythia.next(): break  # Debuging <==> Check for errors

    # Collect particle information
    for particle in pythia.event:
        px.push_back(particle.px())
        py.push_back(particle.py())
        pz.push_back(particle.pz())
        pt.push_back(particle.pT())
        eta.push_back(particle.eta())
        phi.push_back(particle.phi())
        pid.push_back(particle.id())

    # Fill the tree for this event
    tree.Fill()

    # Clear vectors for the next event
    px.clear()
    py.clear()
    pz.clear()
    pt.clear()
    eta.clear()
    phi.clear()
    pid.clear()

# Write to ROOT tree file and close it: K.O.
file.Write()
file.Close()

print("ALICE Au+Au simulation complete. Data saved to alice_tree.root")
# Out:
# ALICE Au+Au simulation complete. Data saved to alice_tree.root
#
#  *------------------------------------------------------------------------------------*
#  |                                                                                    |
#  |  *------------------------------------------------------------------------------*  |
#  |  |                                                                              |  |
#  |  |                                                                              |  |
#  |  |   PPP   Y   Y  TTTTT  H   H  III    A      Welcome to the Lund Monte Carlo!  |  |
#  |  |   P  P   Y Y     T    H   H   I    A A     This is PYTHIA version 8.310      |  |
#  |  |   PPP     Y      T    HHHHH   I   AAAAA    Last date of change: 25 Jul 2023  |  |
#  |  |   P       Y      T    H   H   I   A   A                                      |  |
#  |  |   P       Y      T    H   H  III  A   A    Now is 12 Feb 2024 at 14:19:17    |  |
#  |  |                                                                              |  |
#  |  |   Program documentation and an archive of historic versions is found on:     |  |
#  |  |                                                                              |  |
#  |  |                               https://pythia.org/                            |  |
#  |  |                                                                              |  |
#  |  |   PYTHIA is authored by a collaboration consisting of:                       |  |
#  |  |                                                                              |  |
#  |  |   Christian Bierlich, Naomi Cooke, Nishita Desai, Leif Gellersen,            |  |
#  |  |   Ilkka Helenius, Philip Ilten, Leif Lonnblad, Stephen Mrenna,               |  |
#  |  |   Stefan Prestel, Christian Preuss, Torbjorn Sjostrand, Peter Skands,        |  |
#  |  |   Marius Utheim and Rob Verheyen.                                            |  |
#  |  |                                                                              |  |
#  |  |   The complete list of authors, including contact information and            |  |
#  |  |   affiliations, can be found on https://pythia.org/.                         |  |
#  |  |   Problems or bugs should be reported on email at authors@pythia.org.        |  |
#  |  |                                                                              |  |
#  |  |   The main program reference is C. Bierlich et al,                           |  |
#  |  |   'A comprehensive guide to the physics and usage of Pythia 8.3',            |  |
#  |  |   SciPost Phys. Codebases 8-r8.3 (2022) [arXiv:2203.11601 [hep-ph]]          |  |
#  |  |                                                                              |  |
#  |  |   PYTHIA is released under the GNU General Public Licence version 2 or later.|  |
#  |  |   Please respect the MCnet Guidelines for Event Generator Authors and Users. |  |
#  |  |                                                                              |  |
#  |  |   Disclaimer: this program comes without any guarantees.                     |  |
#  |  |   Beware of errors and use common sense when interpreting results.           |  |
#  |  |                                                                              |  |
#  |  |   Copyright (C) 2023 Torbjorn Sjostrand                                      |  |
#  |  |                                                                              |  |
#  |  |                                                                              |  |
#  |  *------------------------------------------------------------------------------*  |
#  |                                                                                    |
#  *------------------------------------------------------------------------------------*
#
#  *----------------------  Initializing Angantyr  ----------------------*
#  |                    We collide: 208Pb on p+                          |
#  |                                                                     |
#  |                    Below follows initialization                     |
#  |                    of sub-collisions.                               |
#  |                                                                     |
#  |                   //>________________________________               |
#  |          [########[]_________________________________>              |
#  |                   \\>                                               |
#  |                                                                     |
#  *------ HeavyIon fitting of SubCollisionModel to cross sections ------*
#  |                                                                     |
#  |   Fitting parameters for  13000.0 GeV                               |
#  |   ....................                                              |
#  |                                                                     |
#  |     Resulting parameters:                                           |
#  |                       [0]:   53.38                                  |
#  |                       [1]:    1.85                                  |
#  |                       [2]:    0.72                                  |
#  |                                                                     |
#  |     Resulting cross sections        (target value)                  |
#  |                    Total:   100.61 *(100.30 +-  2%) mb              |
#  |          non-diffractive:    54.22 *( 53.64 +-  2%) mb              |
#  |           XX diffractive:     9.69 *( 10.18 +- 10%) mb              |
#  |       wounded target (B):    70.64 *( 70.93 +-  5%) mb              |
#  |   wounded projectile (A):    70.66 *( 70.93 +-  5%) mb              |
#  |          AXB diffractive:     0.00  (  0.00       ) mb              |
#  |                  elastic:    23.22 *( 22.26 +- 10%) mb              |
#  |          elastic b-slope:    28.38  ( 23.49       ) GeV^-2          |
#  |                                                                     |
#  |                 Chi2/Ndf:     0.25                                  |
#  |                                                                     |
#  *--- End HeavyIon fitting of parameters in nucleon collision model ---*
#
#  To avoid refitting, add the following lines to your configuration file:
#   HeavyIon:SigFitNGen = 0
#   HeavyIon:SigFitDefPar = 53.38,1.85,0.72
#
#  Angantyr Info: Initializing minimum bias processes.
#
#  *-------  PYTHIA Process Initialization  --------------------------*
#  |                                                                  |
#  | We collide p+ with p+ at a CM energy of 1.300e+04 GeV            |
#  |                                                                  |
#  |------------------------------------------------------------------|
#  |                                                    |             |
#  | Subprocess                                    Code |   Estimated |
#  |                                                    |    max (mb) |
#  |                                                    |             |
#  |------------------------------------------------------------------|
#  |                                                    |             |
#  | non-diffractive                                101 |   5.364e+01 |
#  | A B -> A B elastic                             102 |   2.226e+01 |
#  | A B -> X B single diffractive                  103 |   7.119e+00 |
#  | A B -> A X single diffractive                  104 |   7.119e+00 |
#  | A B -> X X double diffractive                  105 |   1.018e+01 |
#  | A B -> A X B central diffractive               106 |   0.000e+00 |
#  |                                                                  |
#  *-------  End PYTHIA Process Initialization -----------------------*
#
#  *-------  PYTHIA Multiparton Interactions Initialization  ---------*
#  |                                                                  |
#  |                   sigmaNonDiffractive =    53.64 mb              |
#  |                                                                  |
#  |    pT0 =  3.62 gives sigmaInteraction =   188.08 mb: accepted    |
#  |                                                                  |
#  *-------  End PYTHIA Multiparton Interactions Initialization  -----*
#
#  *-------  PYTHIA Multiparton Interactions Initialization  ---------*
#  |                                                                  |
#  |   diffraction XB for p+ on p+                                    |
#  |                                                                  |
#  |   diffractive mass = 1.00e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  0.65 gives sigmaInteraction =    12.47 mb: accepted    |
#  |   diffractive mass = 1.61e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  0.73 gives sigmaInteraction =    12.69 mb: accepted    |
#  |   diffractive mass = 2.60e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  0.81 gives sigmaInteraction =    12.51 mb: accepted    |
#  |   diffractive mass = 4.20e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  0.91 gives sigmaInteraction =    12.04 mb: accepted    |
#  |   diffractive mass = 6.77e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.02 gives sigmaInteraction =    11.58 mb: accepted    |
#  |   diffractive mass = 1.09e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.15 gives sigmaInteraction =    11.26 mb: accepted    |
#  |   diffractive mass = 1.76e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.29 gives sigmaInteraction =    11.38 mb: accepted    |
#  |   diffractive mass = 2.84e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.44 gives sigmaInteraction =    11.96 mb: accepted    |
#  |   diffractive mass = 4.58e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.62 gives sigmaInteraction =    12.82 mb: accepted    |
#  |   diffractive mass = 7.39e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.82 gives sigmaInteraction =    14.41 mb: accepted    |
#  |   diffractive mass = 1.19e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  2.04 gives sigmaInteraction =    16.22 mb: accepted    |
#  |   diffractive mass = 1.92e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  2.29 gives sigmaInteraction =    18.66 mb: accepted    |
#  |   diffractive mass = 3.10e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  2.56 gives sigmaInteraction =    21.52 mb: accepted    |
#  |   diffractive mass = 5.00e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  2.87 gives sigmaInteraction =    24.64 mb: accepted    |
#  |   diffractive mass = 8.06e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  3.22 gives sigmaInteraction =    28.55 mb: accepted    |
#  |   diffractive mass = 1.30e+04 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  3.62 gives sigmaInteraction =    32.40 mb: accepted    |
#  |                                                                  |
#  *-------  End PYTHIA Multiparton Interactions Initialization  -----*
#  PYTHIA Warning in MultipartonInteractions::init: maximum increased by factor 4.717
#
#  *-------  PYTHIA Multiparton Interactions Initialization  ---------*
#  |                                                                  |
#  |   diffraction AX for p+ on p+                                    |
#  |                                                                  |
#  |   diffractive mass = 1.00e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  0.65 gives sigmaInteraction =    12.43 mb: accepted    |
#  |   diffractive mass = 1.61e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  0.73 gives sigmaInteraction =    12.78 mb: accepted    |
#  |   diffractive mass = 2.60e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  0.81 gives sigmaInteraction =    12.47 mb: accepted    |
#  |   diffractive mass = 4.20e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  0.91 gives sigmaInteraction =    12.02 mb: accepted    |
#  |   diffractive mass = 6.77e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.02 gives sigmaInteraction =    11.57 mb: accepted    |
#  |   diffractive mass = 1.09e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.15 gives sigmaInteraction =    11.31 mb: accepted    |
#  |   diffractive mass = 1.76e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.29 gives sigmaInteraction =    11.46 mb: accepted    |
#  |   diffractive mass = 2.84e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.44 gives sigmaInteraction =    11.99 mb: accepted    |
#  |   diffractive mass = 4.58e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.62 gives sigmaInteraction =    12.91 mb: accepted    |
#  |   diffractive mass = 7.39e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.82 gives sigmaInteraction =    14.49 mb: accepted    |
#  |   diffractive mass = 1.19e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  2.04 gives sigmaInteraction =    16.24 mb: accepted    |
#  |   diffractive mass = 1.92e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  2.29 gives sigmaInteraction =    18.62 mb: accepted    |
#  |   diffractive mass = 3.10e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  2.56 gives sigmaInteraction =    21.38 mb: accepted    |
#  |   diffractive mass = 5.00e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  2.87 gives sigmaInteraction =    25.02 mb: accepted    |
#  |   diffractive mass = 8.06e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  3.22 gives sigmaInteraction =    28.51 mb: accepted    |
#  |   diffractive mass = 1.30e+04 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  3.62 gives sigmaInteraction =    32.37 mb: accepted    |
#  |                                                                  |
#  *-------  End PYTHIA Multiparton Interactions Initialization  -----*
#
#  *-------  PYTHIA Multiparton Interactions Initialization  ---------*
#  |                                                                  |
#  |   diffraction AXB for p+ on p+                                   |
#  |                                                                  |
#  |   diffractive mass = 1.00e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  0.65 gives sigmaInteraction =     2.75 mb: rejected    |
#  |    pT0 =  0.58 gives sigmaInteraction =     3.99 mb: rejected    |
#  |    pT0 =  0.52 gives sigmaInteraction =     5.83 mb: rejected    |
#  |    pT0 =  0.47 gives sigmaInteraction =     8.53 mb: rejected    |
#  |    pT0 =  0.42 gives sigmaInteraction =    12.39 mb: accepted    |
#  |   diffractive mass = 1.61e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  0.73 gives sigmaInteraction =     2.26 mb: rejected    |
#  |    pT0 =  0.65 gives sigmaInteraction =     3.23 mb: rejected    |
#  |    pT0 =  0.59 gives sigmaInteraction =     4.63 mb: rejected    |
#  |    pT0 =  0.53 gives sigmaInteraction =     6.64 mb: rejected    |
#  |    pT0 =  0.48 gives sigmaInteraction =     9.52 mb: rejected    |
#  |    pT0 =  0.43 gives sigmaInteraction =    13.69 mb: accepted    |
#  |   diffractive mass = 2.60e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  0.81 gives sigmaInteraction =     1.83 mb: rejected    |
#  |    pT0 =  0.73 gives sigmaInteraction =     2.57 mb: rejected    |
#  |    pT0 =  0.66 gives sigmaInteraction =     3.60 mb: rejected    |
#  |    pT0 =  0.59 gives sigmaInteraction =     5.06 mb: rejected    |
#  |    pT0 =  0.53 gives sigmaInteraction =     7.16 mb: rejected    |
#  |    pT0 =  0.48 gives sigmaInteraction =    10.26 mb: rejected    |
#  |    pT0 =  0.43 gives sigmaInteraction =    14.53 mb: accepted    |
#  |   diffractive mass = 4.20e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  0.91 gives sigmaInteraction =     1.55 mb: rejected    |
#  |    pT0 =  0.82 gives sigmaInteraction =     2.10 mb: rejected    |
#  |    pT0 =  0.74 gives sigmaInteraction =     2.89 mb: rejected    |
#  |    pT0 =  0.67 gives sigmaInteraction =     3.94 mb: rejected    |
#  |    pT0 =  0.60 gives sigmaInteraction =     5.46 mb: rejected    |
#  |    pT0 =  0.54 gives sigmaInteraction =     7.55 mb: rejected    |
#  |    pT0 =  0.49 gives sigmaInteraction =    10.60 mb: rejected    |
#  |    pT0 =  0.44 gives sigmaInteraction =    14.93 mb: accepted    |
#  |   diffractive mass = 6.77e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.02 gives sigmaInteraction =     1.40 mb: rejected    |
#  |    pT0 =  0.92 gives sigmaInteraction =     1.83 mb: rejected    |
#  |    pT0 =  0.83 gives sigmaInteraction =     2.43 mb: rejected    |
#  |    pT0 =  0.75 gives sigmaInteraction =     3.19 mb: rejected    |
#  |    pT0 =  0.67 gives sigmaInteraction =     4.30 mb: rejected    |
#  |    pT0 =  0.60 gives sigmaInteraction =     5.82 mb: rejected    |
#  |    pT0 =  0.54 gives sigmaInteraction =     7.91 mb: rejected    |
#  |    pT0 =  0.49 gives sigmaInteraction =    11.00 mb: accepted    |
#  |   diffractive mass = 1.09e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.15 gives sigmaInteraction =     1.37 mb: rejected    |
#  |    pT0 =  1.03 gives sigmaInteraction =     1.74 mb: rejected    |
#  |    pT0 =  0.93 gives sigmaInteraction =     2.19 mb: rejected    |
#  |    pT0 =  0.84 gives sigmaInteraction =     2.81 mb: rejected    |
#  |    pT0 =  0.75 gives sigmaInteraction =     3.61 mb: rejected    |
#  |    pT0 =  0.68 gives sigmaInteraction =     4.78 mb: rejected    |
#  |    pT0 =  0.61 gives sigmaInteraction =     6.23 mb: rejected    |
#  |    pT0 =  0.55 gives sigmaInteraction =     8.36 mb: rejected    |
#  |    pT0 =  0.49 gives sigmaInteraction =    11.31 mb: accepted    |
#  |   diffractive mass = 1.76e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.29 gives sigmaInteraction =     1.45 mb: rejected    |
#  |    pT0 =  1.16 gives sigmaInteraction =     1.79 mb: rejected    |
#  |    pT0 =  1.04 gives sigmaInteraction =     2.19 mb: rejected    |
#  |    pT0 =  0.94 gives sigmaInteraction =     2.69 mb: rejected    |
#  |    pT0 =  0.84 gives sigmaInteraction =     3.34 mb: rejected    |
#  |    pT0 =  0.76 gives sigmaInteraction =     4.17 mb: rejected    |
#  |    pT0 =  0.68 gives sigmaInteraction =     5.30 mb: rejected    |
#  |    pT0 =  0.62 gives sigmaInteraction =     6.80 mb: rejected    |
#  |    pT0 =  0.55 gives sigmaInteraction =     8.96 mb: rejected    |
#  |    pT0 =  0.50 gives sigmaInteraction =    11.90 mb: accepted    |
#  |   diffractive mass = 2.84e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.44 gives sigmaInteraction =     1.61 mb: rejected    |
#  |    pT0 =  1.30 gives sigmaInteraction =     1.93 mb: rejected    |
#  |    pT0 =  1.17 gives sigmaInteraction =     2.34 mb: rejected    |
#  |    pT0 =  1.05 gives sigmaInteraction =     2.80 mb: rejected    |
#  |    pT0 =  0.95 gives sigmaInteraction =     3.36 mb: rejected    |
#  |    pT0 =  0.85 gives sigmaInteraction =     4.05 mb: rejected    |
#  |    pT0 =  0.77 gives sigmaInteraction =     5.00 mb: rejected    |
#  |    pT0 =  0.69 gives sigmaInteraction =     6.06 mb: rejected    |
#  |    pT0 =  0.62 gives sigmaInteraction =     7.63 mb: rejected    |
#  |    pT0 =  0.56 gives sigmaInteraction =     9.69 mb: rejected    |
#  |    pT0 =  0.50 gives sigmaInteraction =    12.59 mb: accepted    |
#  |   diffractive mass = 4.58e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.62 gives sigmaInteraction =     1.84 mb: rejected    |
#  |    pT0 =  1.46 gives sigmaInteraction =     2.19 mb: rejected    |
#  |    pT0 =  1.31 gives sigmaInteraction =     2.61 mb: rejected    |
#  |    pT0 =  1.18 gives sigmaInteraction =     3.06 mb: rejected    |
#  |    pT0 =  1.06 gives sigmaInteraction =     3.64 mb: rejected    |
#  |    pT0 =  0.96 gives sigmaInteraction =     4.28 mb: rejected    |
#  |    pT0 =  0.86 gives sigmaInteraction =     5.03 mb: rejected    |
#  |    pT0 =  0.77 gives sigmaInteraction =     5.98 mb: rejected    |
#  |    pT0 =  0.70 gives sigmaInteraction =     7.13 mb: rejected    |
#  |    pT0 =  0.63 gives sigmaInteraction =     8.77 mb: rejected    |
#  |    pT0 =  0.56 gives sigmaInteraction =    10.94 mb: rejected    |
#  |    pT0 =  0.51 gives sigmaInteraction =    13.64 mb: accepted    |
#  |   diffractive mass = 7.39e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.82 gives sigmaInteraction =     2.08 mb: rejected    |
#  |    pT0 =  1.64 gives sigmaInteraction =     2.50 mb: rejected    |
#  |    pT0 =  1.47 gives sigmaInteraction =     2.95 mb: rejected    |
#  |    pT0 =  1.32 gives sigmaInteraction =     3.48 mb: rejected    |
#  |    pT0 =  1.19 gives sigmaInteraction =     4.03 mb: rejected    |
#  |    pT0 =  1.07 gives sigmaInteraction =     4.68 mb: rejected    |
#  |    pT0 =  0.97 gives sigmaInteraction =     5.43 mb: rejected    |
#  |    pT0 =  0.87 gives sigmaInteraction =     6.26 mb: rejected    |
#  |    pT0 =  0.78 gives sigmaInteraction =     7.29 mb: rejected    |
#  |    pT0 =  0.70 gives sigmaInteraction =     8.57 mb: rejected    |
#  |    pT0 =  0.63 gives sigmaInteraction =    10.32 mb: rejected    |
#  |    pT0 =  0.57 gives sigmaInteraction =    12.16 mb: accepted    |
#  |   diffractive mass = 1.19e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  2.04 gives sigmaInteraction =     2.38 mb: rejected    |
#  |    pT0 =  1.83 gives sigmaInteraction =     2.83 mb: rejected    |
#  |    pT0 =  1.65 gives sigmaInteraction =     3.37 mb: rejected    |
#  |    pT0 =  1.49 gives sigmaInteraction =     3.95 mb: rejected    |
#  |    pT0 =  1.34 gives sigmaInteraction =     4.59 mb: rejected    |
#  |    pT0 =  1.20 gives sigmaInteraction =     5.29 mb: rejected    |
#  |    pT0 =  1.08 gives sigmaInteraction =     6.05 mb: rejected    |
#  |    pT0 =  0.97 gives sigmaInteraction =     6.93 mb: rejected    |
#  |    pT0 =  0.88 gives sigmaInteraction =     7.85 mb: rejected    |
#  |    pT0 =  0.79 gives sigmaInteraction =     9.00 mb: rejected    |
#  |    pT0 =  0.71 gives sigmaInteraction =    10.20 mb: rejected    |
#  |    pT0 =  0.64 gives sigmaInteraction =    11.99 mb: accepted    |
#  |   diffractive mass = 1.92e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  2.29 gives sigmaInteraction =     2.69 mb: rejected    |
#  |    pT0 =  2.06 gives sigmaInteraction =     3.21 mb: rejected    |
#  |    pT0 =  1.85 gives sigmaInteraction =     3.82 mb: rejected    |
#  |    pT0 =  1.67 gives sigmaInteraction =     4.46 mb: rejected    |
#  |    pT0 =  1.50 gives sigmaInteraction =     5.15 mb: rejected    |
#  |    pT0 =  1.35 gives sigmaInteraction =     5.93 mb: rejected    |
#  |    pT0 =  1.21 gives sigmaInteraction =     6.80 mb: rejected    |
#  |    pT0 =  1.09 gives sigmaInteraction =     7.67 mb: rejected    |
#  |    pT0 =  0.98 gives sigmaInteraction =     8.66 mb: rejected    |
#  |    pT0 =  0.89 gives sigmaInteraction =     9.75 mb: rejected    |
#  |    pT0 =  0.80 gives sigmaInteraction =    11.02 mb: accepted    |
#  |   diffractive mass = 3.10e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  2.56 gives sigmaInteraction =     2.99 mb: rejected    |
#  |    pT0 =  2.31 gives sigmaInteraction =     3.58 mb: rejected    |
#  |    pT0 =  2.08 gives sigmaInteraction =     4.27 mb: rejected    |
#  |    pT0 =  1.87 gives sigmaInteraction =     5.00 mb: rejected    |
#  |    pT0 =  1.68 gives sigmaInteraction =     5.78 mb: rejected    |
#  |    pT0 =  1.51 gives sigmaInteraction =     6.66 mb: rejected    |
#  |    pT0 =  1.36 gives sigmaInteraction =     7.63 mb: rejected    |
#  |    pT0 =  1.23 gives sigmaInteraction =     8.72 mb: rejected    |
#  |    pT0 =  1.10 gives sigmaInteraction =     9.62 mb: rejected    |
#  |    pT0 =  0.99 gives sigmaInteraction =    10.87 mb: rejected    |
#  |    pT0 =  0.89 gives sigmaInteraction =    12.17 mb: accepted    |
#  |   diffractive mass = 5.00e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  2.87 gives sigmaInteraction =     3.28 mb: rejected    |
#  |    pT0 =  2.59 gives sigmaInteraction =     3.95 mb: rejected    |
#  |    pT0 =  2.33 gives sigmaInteraction =     4.71 mb: rejected    |
#  |    pT0 =  2.10 gives sigmaInteraction =     5.49 mb: rejected    |
#  |    pT0 =  1.89 gives sigmaInteraction =     6.43 mb: rejected    |
#  |    pT0 =  1.70 gives sigmaInteraction =     7.50 mb: rejected    |
#  |    pT0 =  1.53 gives sigmaInteraction =     8.60 mb: rejected    |
#  |    pT0 =  1.38 gives sigmaInteraction =     9.55 mb: rejected    |
#  |    pT0 =  1.24 gives sigmaInteraction =    10.87 mb: rejected    |
#  |    pT0 =  1.11 gives sigmaInteraction =    12.25 mb: accepted    |
#  |   diffractive mass = 8.06e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  3.22 gives sigmaInteraction =     3.54 mb: rejected    |
#  |    pT0 =  2.90 gives sigmaInteraction =     4.30 mb: rejected    |
#  |    pT0 =  2.61 gives sigmaInteraction =     5.16 mb: rejected    |
#  |    pT0 =  2.35 gives sigmaInteraction =     6.09 mb: rejected    |
#  |    pT0 =  2.12 gives sigmaInteraction =     7.07 mb: rejected    |
#  |    pT0 =  1.90 gives sigmaInteraction =     8.17 mb: rejected    |
#  |    pT0 =  1.71 gives sigmaInteraction =     9.48 mb: rejected    |
#  |    pT0 =  1.54 gives sigmaInteraction =    10.73 mb: rejected    |
#  |    pT0 =  1.39 gives sigmaInteraction =    12.15 mb: accepted    |
#  |   diffractive mass = 1.30e+04 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  3.62 gives sigmaInteraction =     3.81 mb: rejected    |
#  |    pT0 =  3.25 gives sigmaInteraction =     4.63 mb: rejected    |
#  |    pT0 =  2.93 gives sigmaInteraction =     5.53 mb: rejected    |
#  |    pT0 =  2.64 gives sigmaInteraction =     6.50 mb: rejected    |
#  |    pT0 =  2.37 gives sigmaInteraction =     7.63 mb: rejected    |
#  |    pT0 =  2.14 gives sigmaInteraction =     8.86 mb: rejected    |
#  |    pT0 =  1.92 gives sigmaInteraction =    10.19 mb: rejected    |
#  |    pT0 =  1.73 gives sigmaInteraction =    11.77 mb: accepted    |
#  |                                                                  |
#  *-------  End PYTHIA Multiparton Interactions Initialization  -----*
#
#  *-------  PYTHIA Flag + Mode + Parm + Word + FVec + MVec + PVec + WVec Settings (changes only)  ------------------*
#  |                                                                                                                 |
#  | Name                                          |                      Now |      Default         Min         Max |
#  |                                               |                          |                                      |
#  | BeamRemnants:halfScaleForKT                   |                  1.00000 |      1.50000         0.0             |
#  | BeamRemnants:primordialKThard                 |                  2.00000 |      1.80000         0.0             |
#  | BeamRemnants:primordialKTsoft                 |                  0.50000 |      0.90000         0.0             |
#  | Beams:eCM                                     |                13000.000 |    14000.000         0.0             |
#  | ColourReconnection:range                      |                 10.00000 |      1.80000         0.0    10.00000 |
#  | Diffraction:largeMassSuppress                 |                  2.00000 |      4.00000         0.0             |
#  | HadronLevel:all                               |                      off |           on                         |
#  | MultipartonInteractions:alphaSvalue           |                  0.12700 |      0.13000   0.0600000     0.25000 |
#  | MultipartonInteractions:bProfile              |                        1 |            3           0           4 |
#  | MultipartonInteractions:ecmPow                |                  0.24000 |      0.21500         0.0     0.50000 |
#  | MultipartonInteractions:ecmRef                |                 1800.000 |     7000.000     1.00000             |
#  | MultipartonInteractions:expPow                |                  1.00000 |      1.85000     0.40000    10.00000 |
#  | MultipartonInteractions:pT0Ref                |                  2.25000 |      2.28000     0.50000    10.00000 |
#  | Next:numberCount                              |                        0 |         1000           0             |
#  | Next:numberShowEvent                          |                        0 |            1           0             |
#  | Next:numberShowInfo                           |                        0 |            1           0             |
#  | Next:numberShowLHA                            |                        0 |            1           0             |
#  | Next:numberShowProcess                        |                        0 |            1           0             |
#  | PDF:pSet                                      |                        2 |           13                         |
#  | SigmaDiffractive:dampen                       |                      off |           on                         |
#  | SigmaProcess:alphaSvalue                      |                  0.12650 |      0.13000   0.0600000     0.25000 |
#  | SoftQCD:all                                   |                       on |          off                         |
#  | SpaceShower:alphaSvalue                       |                  0.13700 |      0.13650   0.0600000     0.25000 |
#  | SpaceShower:ecmRef                            |                 1800.000 |     7000.000     1.00000             |
#  | SpaceShower:phiIntAsym                        |                      off |           on                         |
#  | SpaceShower:phiPolAsym                        |                      off |           on                         |
#  | SpaceShower:rapidityOrder                     |                      off |           on                         |
#  | SpaceShower:rapidityOrderMPI                  |                      off |           on                         |
#  | StringFlav:etaSup                             |                  0.63000 |      0.60000         0.0     1.00000 |
#  | StringFlav:mesonBvector                       |                  3.00000 |      2.20000         0.0     3.00000 |
#  | StringFlav:mesonCvector                       |                  1.06000 |      0.88000         0.0     3.00000 |
#  | StringFlav:mesonSvector                       |                  0.72500 |      0.55000         0.0     3.00000 |
#  | StringFlav:mesonUDvector                      |                  0.62000 |      0.50000         0.0     3.00000 |
#  | StringFlav:popcornSpair                       |                  0.50000 |      0.90000         0.0     1.00000 |
#  | StringFlav:probQQ1toQQ0                       |                0.0270000 |    0.0275000         0.0     1.00000 |
#  | StringFlav:probQQtoQ                          |                0.0900000 |    0.0810000         0.0     1.00000 |
#  | StringFlav:probSQtoQQ                         |                  1.00000 |      0.91500         0.0     1.00000 |
#  | StringFlav:probStoUD                          |                  0.19000 |      0.21700         0.0     1.00000 |
#  | StringPT:sigma                                |                  0.30400 |      0.33500         0.0     1.00000 |
#  | StringZ:aExtraDiquark                         |                  0.50000 |      0.97000         0.0     2.00000 |
#  | StringZ:aLund                                 |                  0.30000 |      0.68000         0.0     2.00000 |
#  | StringZ:bLund                                 |                  0.80000 |      0.98000     0.20000     2.00000 |
#  | StringZ:rFactB                                |                  0.67000 |      0.85500         0.0     2.00000 |
#  | StringZ:rFactC                                |                  1.00000 |      1.32000         0.0     2.00000 |
#  | TimeShower:alphaSvalue                        |                  0.13830 |      0.13650   0.0600000     0.25000 |
#  | TimeShower:dampenBeamRecoil                   |                      off |           on                         |
#  | TimeShower:phiPolAsym                         |                      off |           on                         |
#  | TimeShower:pTmin                              |                  0.40000 |      0.50000     0.10000     2.00000 |
#  | TimeShower:pTminChgQ                          |                  0.40000 |      0.50000     0.10000     2.00000 |
#  | Tune:ee                                       |                        0 |            7          -1           7 |
#  | Tune:pp                                       |                        0 |           14          -1          34 |
#  |                                                                                                                 |
#  *-------  End PYTHIA Flag + Mode + Parm + Word + FVec + MVec + PVec + WVec Settings  -----------------------------*
#
#  --------  PYTHIA Particle Data Table (changed only)  ------------------------------------------------------------------------------
#
#       id   name            antiName         spn chg col      m0        mWidth      mMin       mMax       tau0    res dec ext vis wid
#              no onMode   bRatio   meMode     products
#
#  no particle data has been changed from its default value
#
#  --------  End PYTHIA Particle Data Table  -----------------------------------------------------------------------------------------
#
#  Angantyr Info: Initializing secondary absorptive processes as single diffraction..
#
#  *-------  PYTHIA Process Initialization  --------------------------*
#  |                                                                  |
#  | We collide p+ with p+ at a CM energy of 1.300e+04 GeV            |
#  |                                                                  |
#  |------------------------------------------------------------------|
#  |                                                    |             |
#  | Subprocess                                    Code |   Estimated |
#  |                                                    |    max (mb) |
#  |                                                    |             |
#  |------------------------------------------------------------------|
#  |                                                    |             |
#  | A B -> X B single diffractive                  103 |   6.416e+00 |
#  | A B -> A X single diffractive                  104 |   6.416e+00 |
#  |                                                                  |
#  *-------  End PYTHIA Process Initialization -----------------------*
#
#  *-------  PYTHIA Multiparton Interactions Initialization  ---------*
#  |                                                                  |
#  |                   sigmaNonDiffractive =    56.42 mb              |
#  |                                                                  |
#  |    pT0 =  2.60 gives sigmaInteraction =   317.79 mb: accepted    |
#  |                                                                  |
#  *-------  End PYTHIA Multiparton Interactions Initialization  -----*
#
#  *-------  PYTHIA Multiparton Interactions Initialization  ---------*
#  |                                                                  |
#  |   diffraction XB for p+ on p+                                    |
#  |                                                                  |
#  |   diffractive mass = 1.00e+01 GeV and sigmaNorm =    53.64 mb    |
#  |    pT0 =  2.60 gives sigmaInteraction =    18.28 mb: rejected    |
#  |    pT0 =  2.34 gives sigmaInteraction =    28.71 mb: rejected    |
#  |    pT0 =  2.11 gives sigmaInteraction =    44.86 mb: rejected    |
#  |    pT0 =  1.90 gives sigmaInteraction =    70.46 mb: accepted    |
#  |   diffractive mass = 1.61e+01 GeV and sigmaNorm =    53.64 mb    |
#  |    pT0 =  2.60 gives sigmaInteraction =    27.24 mb: rejected    |
#  |    pT0 =  2.34 gives sigmaInteraction =    41.96 mb: rejected    |
#  |    pT0 =  2.11 gives sigmaInteraction =    63.86 mb: accepted    |
#  |   diffractive mass = 2.60e+01 GeV and sigmaNorm =    53.64 mb    |
#  |    pT0 =  2.60 gives sigmaInteraction =    37.04 mb: rejected    |
#  |    pT0 =  2.34 gives sigmaInteraction =    55.46 mb: rejected    |
#  |    pT0 =  2.11 gives sigmaInteraction =    82.92 mb: accepted    |
#  |   diffractive mass = 4.20e+01 GeV and sigmaNorm =    53.64 mb    |
#  |    pT0 =  2.60 gives sigmaInteraction =    47.62 mb: rejected    |
#  |    pT0 =  2.34 gives sigmaInteraction =    69.76 mb: accepted    |
#  |   diffractive mass = 6.77e+01 GeV and sigmaNorm =    53.64 mb    |
#  |    pT0 =  2.60 gives sigmaInteraction =    61.22 mb: accepted    |
#  |   diffractive mass = 1.09e+02 GeV and sigmaNorm =    53.64 mb    |
#  |    pT0 =  2.60 gives sigmaInteraction =    78.88 mb: accepted    |
#  |   diffractive mass = 1.76e+02 GeV and sigmaNorm =    53.64 mb    |
#  |    pT0 =  2.60 gives sigmaInteraction =   100.54 mb: accepted    |
#  |   diffractive mass = 2.84e+02 GeV and sigmaNorm =    53.64 mb    |
#  |    pT0 =  2.60 gives sigmaInteraction =   123.29 mb: accepted    |
#  |   diffractive mass = 4.58e+02 GeV and sigmaNorm =    53.64 mb    |
#  |    pT0 =  2.60 gives sigmaInteraction =   150.22 mb: accepted    |
#  |   diffractive mass = 7.39e+02 GeV and sigmaNorm =    53.64 mb    |
#  |    pT0 =  2.60 gives sigmaInteraction =   177.73 mb: accepted    |
#  |   diffractive mass = 1.19e+03 GeV and sigmaNorm =    53.64 mb    |
#  |    pT0 =  2.60 gives sigmaInteraction =   206.91 mb: accepted    |
#  |   diffractive mass = 1.92e+03 GeV and sigmaNorm =    53.64 mb    |
#  |    pT0 =  2.60 gives sigmaInteraction =   234.55 mb: accepted    |
#  |   diffractive mass = 3.10e+03 GeV and sigmaNorm =    53.64 mb    |
#  |    pT0 =  2.60 gives sigmaInteraction =   261.27 mb: accepted    |
#  |   diffractive mass = 5.00e+03 GeV and sigmaNorm =    53.64 mb    |
#  |    pT0 =  2.60 gives sigmaInteraction =   281.19 mb: accepted    |
#  |   diffractive mass = 8.06e+03 GeV and sigmaNorm =    53.64 mb    |
#  |    pT0 =  2.60 gives sigmaInteraction =   295.10 mb: accepted    |
#  |   diffractive mass = 1.30e+04 GeV and sigmaNorm =    53.64 mb    |
#  |    pT0 =  2.60 gives sigmaInteraction =   296.91 mb: accepted    |
#  |                                                                  |
#  *-------  End PYTHIA Multiparton Interactions Initialization  -----*
#  PYTHIA Warning in MultipartonInteractions::init: maximum increased by factor 1.839
#
#  *-------  PYTHIA Multiparton Interactions Initialization  ---------*
#  |                                                                  |
#  |   diffraction AX for p+ on p+                                    |
#  |                                                                  |
#  |   diffractive mass = 1.00e+01 GeV and sigmaNorm =    53.64 mb    |
#  |    pT0 =  2.60 gives sigmaInteraction =    18.34 mb: rejected    |
#  |    pT0 =  2.34 gives sigmaInteraction =    28.85 mb: rejected    |
#  |    pT0 =  2.11 gives sigmaInteraction =    44.97 mb: rejected    |
#  |    pT0 =  1.90 gives sigmaInteraction =    70.77 mb: accepted    |
#  |   diffractive mass = 1.61e+01 GeV and sigmaNorm =    53.64 mb    |
#  |    pT0 =  2.60 gives sigmaInteraction =    27.20 mb: rejected    |
#  |    pT0 =  2.34 gives sigmaInteraction =    41.66 mb: rejected    |
#  |    pT0 =  2.11 gives sigmaInteraction =    64.01 mb: accepted    |
#  |   diffractive mass = 2.60e+01 GeV and sigmaNorm =    53.64 mb    |
#  |    pT0 =  2.60 gives sigmaInteraction =    36.95 mb: rejected    |
#  |    pT0 =  2.34 gives sigmaInteraction =    55.41 mb: rejected    |
#  |    pT0 =  2.11 gives sigmaInteraction =    83.03 mb: accepted    |
#  |   diffractive mass = 4.20e+01 GeV and sigmaNorm =    53.64 mb    |
#  |    pT0 =  2.60 gives sigmaInteraction =    47.61 mb: rejected    |
#  |    pT0 =  2.34 gives sigmaInteraction =    69.71 mb: accepted    |
#  |   diffractive mass = 6.77e+01 GeV and sigmaNorm =    53.64 mb    |
#  |    pT0 =  2.60 gives sigmaInteraction =    61.14 mb: accepted    |
#  |   diffractive mass = 1.09e+02 GeV and sigmaNorm =    53.64 mb    |
#  |    pT0 =  2.60 gives sigmaInteraction =    78.31 mb: accepted    |
#  |   diffractive mass = 1.76e+02 GeV and sigmaNorm =    53.64 mb    |
#  |    pT0 =  2.60 gives sigmaInteraction =    99.83 mb: accepted    |
#  |   diffractive mass = 2.84e+02 GeV and sigmaNorm =    53.64 mb    |
#  |    pT0 =  2.60 gives sigmaInteraction =   122.79 mb: accepted    |
#  |   diffractive mass = 4.58e+02 GeV and sigmaNorm =    53.64 mb    |
#  |    pT0 =  2.60 gives sigmaInteraction =   150.45 mb: accepted    |
#  |   diffractive mass = 7.39e+02 GeV and sigmaNorm =    53.64 mb    |
#  |    pT0 =  2.60 gives sigmaInteraction =   178.70 mb: accepted    |
#  |   diffractive mass = 1.19e+03 GeV and sigmaNorm =    53.64 mb    |
#  |    pT0 =  2.60 gives sigmaInteraction =   207.61 mb: accepted    |
#  |   diffractive mass = 1.92e+03 GeV and sigmaNorm =    53.64 mb    |
#  |    pT0 =  2.60 gives sigmaInteraction =   233.18 mb: accepted    |
#  |   diffractive mass = 3.10e+03 GeV and sigmaNorm =    53.64 mb    |
#  |    pT0 =  2.60 gives sigmaInteraction =   261.80 mb: accepted    |
#  |   diffractive mass = 5.00e+03 GeV and sigmaNorm =    53.64 mb    |
#  |    pT0 =  2.60 gives sigmaInteraction =   281.39 mb: accepted    |
#  |   diffractive mass = 8.06e+03 GeV and sigmaNorm =    53.64 mb    |
#  |    pT0 =  2.60 gives sigmaInteraction =   294.72 mb: accepted    |
#  |   diffractive mass = 1.30e+04 GeV and sigmaNorm =    53.64 mb    |
#  |    pT0 =  2.60 gives sigmaInteraction =   296.95 mb: accepted    |
#  |                                                                  |
#  *-------  End PYTHIA Multiparton Interactions Initialization  -----*
#
#  *-------  PYTHIA Flag + Mode + Parm + Word + FVec + MVec + PVec + WVec Settings (changes only)  ------------------*
#  |                                                                                                                 |
#  | Name                                          |                      Now |      Default         Min         Max |
#  |                                               |                          |                                      |
#  | Beams:eCM                                     |                13000.000 |    14000.000         0.0             |
#  | ColourReconnection:range                      |                 10.00000 |      1.80000         0.0    10.00000 |
#  | Diffraction:mRefPomP                          |                13000.000 |    100.00000     1.00000             |
#  | Diffraction:sigmaRefPomP                      |                 53.63591 |     10.00000     2.00000    40.00000 |
#  | HadronLevel:all                               |                      off |           on                         |
#  | MultipartonInteractions:ecmPow                |                      0.0 |      0.21500         0.0     0.50000 |
#  | MultipartonInteractions:ecmRef                |                13000.000 |     7000.000     1.00000             |
#  | MultipartonInteractions:pT0Ref                |                  2.60457 |      2.28000     0.50000    10.00000 |
#  | Next:numberCount                              |                        0 |         1000           0             |
#  | Next:numberShowEvent                          |                        0 |            1           0             |
#  | Next:numberShowInfo                           |                        0 |            1           0             |
#  | Next:numberShowLHA                            |                        0 |            1           0             |
#  | Next:numberShowProcess                        |                        0 |            1           0             |
#  | PDF:PomSet                                    |                       11 |            6                         |
#  | SigmaProcess:alphaSvalue                      |                  0.12650 |      0.13000   0.0600000     0.25000 |
#  | SoftQCD:singleDiffractive                     |                       on |          off                         |
#  | SpaceShower:alphaSvalue                       |                  0.13700 |      0.13650   0.0600000     0.25000 |
#  | SpaceShower:ecmRef                            |                 1800.000 |     7000.000     1.00000             |
#  | SpaceShower:phiIntAsym                        |                      off |           on                         |
#  | SpaceShower:phiPolAsym                        |                      off |           on                         |
#  | SpaceShower:rapidityOrder                     |                      off |           on                         |
#  | SpaceShower:rapidityOrderMPI                  |                      off |           on                         |
#  | StringFlav:etaSup                             |                  0.63000 |      0.60000         0.0     1.00000 |
#  | StringFlav:mesonBvector                       |                  3.00000 |      2.20000         0.0     3.00000 |
#  | StringFlav:mesonCvector                       |                  1.06000 |      0.88000         0.0     3.00000 |
#  | StringFlav:mesonSvector                       |                  0.72500 |      0.55000         0.0     3.00000 |
#  | StringFlav:mesonUDvector                      |                  0.62000 |      0.50000         0.0     3.00000 |
#  | StringFlav:popcornSpair                       |                  0.50000 |      0.90000         0.0     1.00000 |
#  | StringFlav:probQQ1toQQ0                       |                0.0270000 |    0.0275000         0.0     1.00000 |
#  | StringFlav:probQQtoQ                          |                0.0900000 |    0.0810000         0.0     1.00000 |
#  | StringFlav:probSQtoQQ                         |                  1.00000 |      0.91500         0.0     1.00000 |
#  | StringFlav:probStoUD                          |                  0.19000 |      0.21700         0.0     1.00000 |
#  | StringPT:sigma                                |                  0.30400 |      0.33500         0.0     1.00000 |
#  | StringZ:aExtraDiquark                         |                  0.50000 |      0.97000         0.0     2.00000 |
#  | StringZ:aLund                                 |                  0.30000 |      0.68000         0.0     2.00000 |
#  | StringZ:bLund                                 |                  0.80000 |      0.98000     0.20000     2.00000 |
#  | StringZ:rFactB                                |                  0.67000 |      0.85500         0.0     2.00000 |
#  | StringZ:rFactC                                |                  1.00000 |      1.32000         0.0     2.00000 |
#  | TimeShower:alphaSvalue                        |                  0.13830 |      0.13650   0.0600000     0.25000 |
#  | TimeShower:dampenBeamRecoil                   |                      off |           on                         |
#  | TimeShower:phiPolAsym                         |                      off |           on                         |
#  | TimeShower:pTmin                              |                  0.40000 |      0.50000     0.10000     2.00000 |
#  | TimeShower:pTminChgQ                          |                  0.40000 |      0.50000     0.10000     2.00000 |
#  | Tune:ee                                       |                        0 |            7          -1           7 |
#  | Tune:pp                                       |                        0 |           14          -1          34 |
#  |                                                                                                                 |
#  *-------  End PYTHIA Flag + Mode + Parm + Word + FVec + MVec + PVec + WVec Settings  -----------------------------*
#
#  --------  PYTHIA Particle Data Table (changed only)  ------------------------------------------------------------------------------
#
#       id   name            antiName         spn chg col      m0        mWidth      mMin       mMax       tau0    res dec ext vis wid
#              no onMode   bRatio   meMode     products
#
#  no particle data has been changed from its default value
#
#  --------  End PYTHIA Particle Data Table  -----------------------------------------------------------------------------------------
#
#  Angantyr Info: Initializing hadronisation processes.
#
#  *-------  PYTHIA Flag + Mode + Parm + Word + FVec + MVec + PVec + WVec Settings (changes only)  ------------------*
#  |                                                                                                                 |
#  | Name                                          |                      Now |      Default         Min         Max |
#  |                                               |                          |                                      |
#  | BeamRemnants:halfScaleForKT                   |                  1.00000 |      1.50000         0.0             |
#  | BeamRemnants:primordialKThard                 |                  2.00000 |      1.80000         0.0             |
#  | BeamRemnants:primordialKTsoft                 |                  0.50000 |      0.90000         0.0             |
#  | Beams:eCM                                     |                13000.000 |    14000.000         0.0             |
#  | Beams:idA                                     |               1000822080 |         2212                         |
#  | ColourReconnection:range                      |                 10.00000 |      1.80000         0.0    10.00000 |
#  | Diffraction:largeMassSuppress                 |                  2.00000 |      4.00000         0.0             |
#  | MultipartonInteractions:alphaSvalue           |                  0.12700 |      0.13000   0.0600000     0.25000 |
#  | MultipartonInteractions:bProfile              |                        1 |            3           0           4 |
#  | MultipartonInteractions:ecmPow                |                  0.24000 |      0.21500         0.0     0.50000 |
#  | MultipartonInteractions:ecmRef                |                 1800.000 |     7000.000     1.00000             |
#  | MultipartonInteractions:expPow                |                  1.00000 |      1.85000     0.40000    10.00000 |
#  | MultipartonInteractions:pT0Ref                |                  2.25000 |      2.28000     0.50000    10.00000 |
#  | Next:numberCount                              |                        0 |         1000           0             |
#  | Next:numberShowEvent                          |                        0 |            1           0             |
#  | Next:numberShowInfo                           |                        0 |            1           0             |
#  | Next:numberShowLHA                            |                        0 |            1           0             |
#  | Next:numberShowProcess                        |                        0 |            1           0             |
#  | PartonLevel:all                               |                      off |           on                         |
#  | PDF:pSet                                      |                        2 |           13                         |
#  | ProcessLevel:all                              |                      off |           on                         |
#  | SigmaDiffractive:dampen                       |                      off |           on                         |
#  | SigmaProcess:alphaSvalue                      |                  0.12650 |      0.13000   0.0600000     0.25000 |
#  | SpaceShower:alphaSvalue                       |                  0.13700 |      0.13650   0.0600000     0.25000 |
#  | SpaceShower:ecmRef                            |                 1800.000 |     7000.000     1.00000             |
#  | SpaceShower:phiIntAsym                        |                      off |           on                         |
#  | SpaceShower:phiPolAsym                        |                      off |           on                         |
#  | SpaceShower:rapidityOrder                     |                      off |           on                         |
#  | SpaceShower:rapidityOrderMPI                  |                      off |           on                         |
#  | StringFlav:etaSup                             |                  0.63000 |      0.60000         0.0     1.00000 |
#  | StringFlav:mesonBvector                       |                  3.00000 |      2.20000         0.0     3.00000 |
#  | StringFlav:mesonCvector                       |                  1.06000 |      0.88000         0.0     3.00000 |
#  | StringFlav:mesonSvector                       |                  0.72500 |      0.55000         0.0     3.00000 |
#  | StringFlav:mesonUDvector                      |                  0.62000 |      0.50000         0.0     3.00000 |
#  | StringFlav:popcornSpair                       |                  0.50000 |      0.90000         0.0     1.00000 |
#  | StringFlav:probQQ1toQQ0                       |                0.0270000 |    0.0275000         0.0     1.00000 |
#  | StringFlav:probQQtoQ                          |                0.0900000 |    0.0810000         0.0     1.00000 |
#  | StringFlav:probSQtoQQ                         |                  1.00000 |      0.91500         0.0     1.00000 |
#  | StringFlav:probStoUD                          |                  0.19000 |      0.21700         0.0     1.00000 |
#  | StringPT:sigma                                |                  0.30400 |      0.33500         0.0     1.00000 |
#  | StringZ:aExtraDiquark                         |                  0.50000 |      0.97000         0.0     2.00000 |
#  | StringZ:aLund                                 |                  0.30000 |      0.68000         0.0     2.00000 |
#  | StringZ:bLund                                 |                  0.80000 |      0.98000     0.20000     2.00000 |
#  | StringZ:rFactB                                |                  0.67000 |      0.85500         0.0     2.00000 |
#  | StringZ:rFactC                                |                  1.00000 |      1.32000         0.0     2.00000 |
#  | TimeShower:alphaSvalue                        |                  0.13830 |      0.13650   0.0600000     0.25000 |
#  | TimeShower:dampenBeamRecoil                   |                      off |           on                         |
#  | TimeShower:phiPolAsym                         |                      off |           on                         |
#  | TimeShower:pTmin                              |                  0.40000 |      0.50000     0.10000     2.00000 |
#  | TimeShower:pTminChgQ                          |                  0.40000 |      0.50000     0.10000     2.00000 |
#  | Tune:ee                                       |                        0 |            7          -1           7 |
#  | Tune:pp                                       |                        0 |           14          -1          34 |
#  |                                                                                                                 |
#  *-------  End PYTHIA Flag + Mode + Parm + Word + FVec + MVec + PVec + WVec Settings  -----------------------------*
#
#  --------  PYTHIA Particle Data Table (changed only)  ------------------------------------------------------------------------------
#
#       id   name            antiName         spn chg col      m0        mWidth      mMin       mMax       tau0    res dec ext vis wid
#              no onMode   bRatio   meMode     products
#
#  no particle data has been changed from its default value
#
#  --------  End PYTHIA Particle Data Table  -----------------------------------------------------------------------------------------
#
#  PYTHIA Error in BeamRemnants::setKinematics: kinematics construction failed after retrying 10 times
#  PYTHIA Warning in SimpleSpaceShower::pT2nextQCD: weight above unity
#  PYTHIA Error in BeamRemnants::setKinematics: kinematics construction failed after retrying 10 times

# %%
# ini Pythia 
pythia = pythia8.Pythia()


pythia.readString("Beams:eCM = 7000.")
pythia.readString("HardQCD:all = on")  # Enable hard QCD processes to study jets

# ... add code for defining your own Higgs production process ...

pythia.readString("Beams:idA = 1000822080; Beams:idB = 1000822080")  # lead ions
#pythia.readString("ParticleDecays:limitTau0 = on")  # Decay all unstable particles
pythia.readString("Tune:pp = 2")  # Monash tune for pp collisions (adapt for Au+Au)
pythia.init()

# Event loop
events = 100  # Number of events to simulate
file = ROOT.TFile("alice_tree_6.root", "RECREATE")  # Create a ROOT file
tree = ROOT.TTree("alice_tree_6", "ALICE_Au+Au6_collisions_13_TeV")

# Create vectors for particle properties
px, py, pz, pt, eta, phi, pid = ROOT.std.vector("double")(), ROOT.std.vector("double")(), ROOT.std.vector("double")(), ROOT.std.vector("double")(), ROOT.std.vector("double")(), ROOT.std.vector("double")(), ROOT.std.vector("int")()

# Create branches by linking them with the vectors
tree.Branch("px", px)
tree.Branch("py", py)
tree.Branch("pz", pz)
tree.Branch("pt", pt)
tree.Branch("eta", eta)
tree.Branch("phi", phi)
tree.Branch("pid", pid)

for i in range(events):
    if not pythia.next(): break  # Debuging ::: Check for errors

    # Collect particle information
    for particle in pythia.event:
        px.push_back(particle.px())
        py.push_back(particle.py())
        pz.push_back(particle.pz())
        pt.push_back(particle.pT())
        eta.push_back(particle.eta())
        phi.push_back(particle.phi())
        pid.push_back(particle.id())

    # Fill the tree for this event
    tree.Fill()

    # Clear vectors for the next event
    px.clear()
    py.clear()
    pz.clear()
    pt.clear()
    eta.clear()
    phi.clear()
    pid.clear()


file.Write()
file.Close()

print("ALICE Ag+Ag simulation complete. Data saved to alice_tree.root")
# Out:
# ALICE Ag+Ag simulation complete. Data saved to alice_tree.root
#
#  *------------------------------------------------------------------------------------*
#  |                                                                                    |
#  |  *------------------------------------------------------------------------------*  |
#  |  |                                                                              |  |
#  |  |                                                                              |  |
#  |  |   PPP   Y   Y  TTTTT  H   H  III    A      Welcome to the Lund Monte Carlo!  |  |
#  |  |   P  P   Y Y     T    H   H   I    A A     This is PYTHIA version 8.310      |  |
#  |  |   PPP     Y      T    HHHHH   I   AAAAA    Last date of change: 25 Jul 2023  |  |
#  |  |   P       Y      T    H   H   I   A   A                                      |  |
#  |  |   P       Y      T    H   H  III  A   A    Now is 12 Feb 2024 at 14:24:29    |  |
#  |  |                                                                              |  |
#  |  |   Program documentation and an archive of historic versions is found on:     |  |
#  |  |                                                                              |  |
#  |  |                               https://pythia.org/                            |  |
#  |  |                                                                              |  |
#  |  |   PYTHIA is authored by a collaboration consisting of:                       |  |
#  |  |                                                                              |  |
#  |  |   Christian Bierlich, Naomi Cooke, Nishita Desai, Leif Gellersen,            |  |
#  |  |   Ilkka Helenius, Philip Ilten, Leif Lonnblad, Stephen Mrenna,               |  |
#  |  |   Stefan Prestel, Christian Preuss, Torbjorn Sjostrand, Peter Skands,        |  |
#  |  |   Marius Utheim and Rob Verheyen.                                            |  |
#  |  |                                                                              |  |
#  |  |   The complete list of authors, including contact information and            |  |
#  |  |   affiliations, can be found on https://pythia.org/.                         |  |
#  |  |   Problems or bugs should be reported on email at authors@pythia.org.        |  |
#  |  |                                                                              |  |
#  |  |   The main program reference is C. Bierlich et al,                           |  |
#  |  |   'A comprehensive guide to the physics and usage of Pythia 8.3',            |  |
#  |  |   SciPost Phys. Codebases 8-r8.3 (2022) [arXiv:2203.11601 [hep-ph]]          |  |
#  |  |                                                                              |  |
#  |  |   PYTHIA is released under the GNU General Public Licence version 2 or later.|  |
#  |  |   Please respect the MCnet Guidelines for Event Generator Authors and Users. |  |
#  |  |                                                                              |  |
#  |  |   Disclaimer: this program comes without any guarantees.                     |  |
#  |  |   Beware of errors and use common sense when interpreting results.           |  |
#  |  |                                                                              |  |
#  |  |   Copyright (C) 2023 Torbjorn Sjostrand                                      |  |
#  |  |                                                                              |  |
#  |  |                                                                              |  |
#  |  *------------------------------------------------------------------------------*  |
#  |                                                                                    |
#  *------------------------------------------------------------------------------------*
#
#  *----------------------  Initializing Angantyr  ----------------------*
#  |                    We collide: 208Pb on p+                          |
#  |                                                                     |
#  |                    Below follows initialization                     |
#  |                    of sub-collisions.                               |
#  |                                                                     |
#  |                   //>________________________________               |
#  |          [########[]_________________________________>              |
#  |                   \\>                                               |
#  |                                                                     |
#  *------ HeavyIon fitting of SubCollisionModel to cross sections ------*
#  |                                                                     |
#  |   Fitting parameters for   7000.0 GeV                               |
#  |   ....................                                              |
#  |                                                                     |
#  |     Resulting parameters:                                           |
#  |                       [0]:   22.24                                  |
#  |                       [1]:    1.45                                  |
#  |                       [2]:    0.15                                  |
#  |                                                                     |
#  |     Resulting cross sections        (target value)                  |
#  |                    Total:    90.75 *( 90.76 +-  2%) mb              |
#  |          non-diffractive:    48.02 *( 48.12 +-  2%) mb              |
#  |           XX diffractive:     8.90 *(  9.26 +- 10%) mb              |
#  |       wounded target (B):    64.24 *( 64.22 +-  5%) mb              |
#  |   wounded projectile (A):    64.19 *( 64.22 +-  5%) mb              |
#  |          AXB diffractive:     0.00  (  0.00       ) mb              |
#  |                  elastic:    19.23 *( 19.70 +- 10%) mb              |
#  |          elastic b-slope:    27.05  ( 21.73       ) GeV^-2          |
#  |                                                                     |
#  |                 Chi2/Ndf:     0.07                                  |
#  |                                                                     |
#  *--- End HeavyIon fitting of parameters in nucleon collision model ---*
#
#  To avoid refitting, add the following lines to your configuration file:
#   HeavyIon:SigFitNGen = 0
#   HeavyIon:SigFitDefPar = 22.24,1.45,0.15
#
#  Angantyr Info: Initializing signal process (pp).
#
#  *-------  PYTHIA Process Initialization  --------------------------*
#  |                                                                  |
#  | We collide p+ with p+ at a CM energy of 7.000e+03 GeV            |
#  |                                                                  |
#  |------------------------------------------------------------------|
#  |                                                    |             |
#  | Subprocess                                    Code |   Estimated |
#  |                                                    |    max (mb) |
#  |                                                    |             |
#  |------------------------------------------------------------------|
#  |                                                    |             |
#  | g g -> g g                                     111 |   1.239e+04 |
#  | g g -> q qbar (uds)                            112 |   7.618e+01 |
#  | q g -> q g                                     113 |   4.813e+03 |
#  | q q(bar)' -> q q(bar)'                         114 |   2.353e+02 |
#  | q qbar -> g g                                  115 |   1.180e+00 |
#  | q qbar -> q' qbar' (uds)                       116 |   3.018e-01 |
#  | g g -> c cbar                                  121 |   4.178e+01 |
#  | q qbar -> c cbar                               122 |   1.277e-01 |
#  | g g -> b bbar                                  123 |   1.864e+00 |
#  | q qbar -> b bbar                               124 |   1.388e-02 |
#  |                                                                  |
#  *-------  End PYTHIA Process Initialization -----------------------*
#
#  *-------  PYTHIA Multiparton Interactions Initialization  ---------*
#  |                                                                  |
#  |                   sigmaNonDiffractive =    48.12 mb              |
#  |                                                                  |
#  |    pT0 =  3.12 gives sigmaInteraction =   152.26 mb: accepted    |
#  |                                                                  |
#  *-------  End PYTHIA Multiparton Interactions Initialization  -----*
#
#  *-------  PYTHIA Flag + Mode + Parm + Word + FVec + MVec + PVec + WVec Settings (changes only)  ------------------*
#  |                                                                                                                 |
#  | Name                                          |                      Now |      Default         Min         Max |
#  |                                               |                          |                                      |
#  | BeamRemnants:halfScaleForKT                   |                  1.00000 |      1.50000         0.0             |
#  | BeamRemnants:primordialKThard                 |                  2.00000 |      1.80000         0.0             |
#  | BeamRemnants:primordialKTsoft                 |                  0.50000 |      0.90000         0.0             |
#  | Beams:eCM                                     |                 7000.000 |    14000.000         0.0             |
#  | ColourReconnection:range                      |                 10.00000 |      1.80000         0.0    10.00000 |
#  | Diffraction:largeMassSuppress                 |                  2.00000 |      4.00000         0.0             |
#  | HadronLevel:all                               |                      off |           on                         |
#  | HardQCD:all                                   |                       on |          off                         |
#  | MultipartonInteractions:alphaSvalue           |                  0.12700 |      0.13000   0.0600000     0.25000 |
#  | MultipartonInteractions:bProfile              |                        1 |            3           0           4 |
#  | MultipartonInteractions:ecmPow                |                  0.24000 |      0.21500         0.0     0.50000 |
#  | MultipartonInteractions:ecmRef                |                 1800.000 |     7000.000     1.00000             |
#  | MultipartonInteractions:expPow                |                  1.00000 |      1.85000     0.40000    10.00000 |
#  | MultipartonInteractions:pT0Ref                |                  2.25000 |      2.28000     0.50000    10.00000 |
#  | Next:numberCount                              |                        0 |         1000           0             |
#  | Next:numberShowEvent                          |                        0 |            1           0             |
#  | Next:numberShowInfo                           |                        0 |            1           0             |
#  | Next:numberShowLHA                            |                        0 |            1           0             |
#  | Next:numberShowProcess                        |                        0 |            1           0             |
#  | PDF:pSet                                      |                        2 |           13                         |
#  | SigmaDiffractive:dampen                       |                      off |           on                         |
#  | SigmaProcess:alphaSvalue                      |                  0.12650 |      0.13000   0.0600000     0.25000 |
#  | SpaceShower:alphaSvalue                       |                  0.13700 |      0.13650   0.0600000     0.25000 |
#  | SpaceShower:ecmRef                            |                 1800.000 |     7000.000     1.00000             |
#  | SpaceShower:phiIntAsym                        |                      off |           on                         |
#  | SpaceShower:phiPolAsym                        |                      off |           on                         |
#  | SpaceShower:rapidityOrder                     |                      off |           on                         |
#  | SpaceShower:rapidityOrderMPI                  |                      off |           on                         |
#  | StringFlav:etaSup                             |                  0.63000 |      0.60000         0.0     1.00000 |
#  | StringFlav:mesonBvector                       |                  3.00000 |      2.20000         0.0     3.00000 |
#  | StringFlav:mesonCvector                       |                  1.06000 |      0.88000         0.0     3.00000 |
#  | StringFlav:mesonSvector                       |                  0.72500 |      0.55000         0.0     3.00000 |
#  | StringFlav:mesonUDvector                      |                  0.62000 |      0.50000         0.0     3.00000 |
#  | StringFlav:popcornSpair                       |                  0.50000 |      0.90000         0.0     1.00000 |
#  | StringFlav:probQQ1toQQ0                       |                0.0270000 |    0.0275000         0.0     1.00000 |
#  | StringFlav:probQQtoQ                          |                0.0900000 |    0.0810000         0.0     1.00000 |
#  | StringFlav:probSQtoQQ                         |                  1.00000 |      0.91500         0.0     1.00000 |
#  | StringFlav:probStoUD                          |                  0.19000 |      0.21700         0.0     1.00000 |
#  | StringPT:sigma                                |                  0.30400 |      0.33500         0.0     1.00000 |
#  | StringZ:aExtraDiquark                         |                  0.50000 |      0.97000         0.0     2.00000 |
#  | StringZ:aLund                                 |                  0.30000 |      0.68000         0.0     2.00000 |
#  | StringZ:bLund                                 |                  0.80000 |      0.98000     0.20000     2.00000 |
#  | StringZ:rFactB                                |                  0.67000 |      0.85500         0.0     2.00000 |
#  | StringZ:rFactC                                |                  1.00000 |      1.32000         0.0     2.00000 |
#  | TimeShower:alphaSvalue                        |                  0.13830 |      0.13650   0.0600000     0.25000 |
#  | TimeShower:dampenBeamRecoil                   |                      off |           on                         |
#  | TimeShower:phiPolAsym                         |                      off |           on                         |
#  | TimeShower:pTmin                              |                  0.40000 |      0.50000     0.10000     2.00000 |
#  | TimeShower:pTminChgQ                          |                  0.40000 |      0.50000     0.10000     2.00000 |
#  | Tune:ee                                       |                        3 |            7          -1           7 |
#  | Tune:pp                                       |                        2 |           14          -1          34 |
#  |                                                                                                                 |
#  *-------  End PYTHIA Flag + Mode + Parm + Word + FVec + MVec + PVec + WVec Settings  -----------------------------*
#
#  --------  PYTHIA Particle Data Table (changed only)  ------------------------------------------------------------------------------
#
#       id   name            antiName         spn chg col      m0        mWidth      mMin       mMax       tau0    res dec ext vis wid
#              no onMode   bRatio   meMode     products
#
#  no particle data has been changed from its default value
#
#  --------  End PYTHIA Particle Data Table  -----------------------------------------------------------------------------------------
#
# Generating a few signal events for signal process (pp) to build up statistics
#  Angantyr Info: Initializing signal process (np).
#
#  *-------  PYTHIA Process Initialization  --------------------------*
#  |                                                                  |
#  | We collide n0 with p+ at a CM energy of 7.000e+03 GeV            |
#  |                                                                  |
#  |------------------------------------------------------------------|
#  |                                                    |             |
#  | Subprocess                                    Code |   Estimated |
#  |                                                    |    max (mb) |
#  |                                                    |             |
#  |------------------------------------------------------------------|
#  |                                                    |             |
#  | g g -> g g                                     111 |   1.239e+04 |
#  | g g -> q qbar (uds)                            112 |   7.618e+01 |
#  | q g -> q g                                     113 |   4.813e+03 |
#  | q q(bar)' -> q q(bar)'                         114 |   2.350e+02 |
#  | q qbar -> g g                                  115 |   1.182e+00 |
#  | q qbar -> q' qbar' (uds)                       116 |   3.008e-01 |
#  | g g -> c cbar                                  121 |   4.178e+01 |
#  | q qbar -> c cbar                               122 |   1.271e-01 |
#  | g g -> b bbar                                  123 |   1.864e+00 |
#  | q qbar -> b bbar                               124 |   1.388e-02 |
#  |                                                                  |
#  *-------  End PYTHIA Process Initialization -----------------------*
#
#  *-------  PYTHIA Multiparton Interactions Initialization  ---------*
#  |                                                                  |
#  |                   sigmaNonDiffractive =    48.12 mb              |
#  |                                                                  |
#  |    pT0 =  3.12 gives sigmaInteraction =   152.57 mb: accepted    |
#  |                                                                  |
#  *-------  End PYTHIA Multiparton Interactions Initialization  -----*
#
#  *-------  PYTHIA Flag + Mode + Parm + Word + FVec + MVec + PVec + WVec Settings (changes only)  ------------------*
#  |                                                                                                                 |
#  | Name                                          |                      Now |      Default         Min         Max |
#  |                                               |                          |                                      |
#  | BeamRemnants:halfScaleForKT                   |                  1.00000 |      1.50000         0.0             |
#  | BeamRemnants:primordialKThard                 |                  2.00000 |      1.80000         0.0             |
#  | BeamRemnants:primordialKTsoft                 |                  0.50000 |      0.90000         0.0             |
#  | Beams:eCM                                     |                 7000.000 |    14000.000         0.0             |
#  | Beams:idA                                     |                     2112 |         2212                         |
#  | ColourReconnection:range                      |                 10.00000 |      1.80000         0.0    10.00000 |
#  | Diffraction:largeMassSuppress                 |                  2.00000 |      4.00000         0.0             |
#  | HadronLevel:all                               |                      off |           on                         |
#  | HardQCD:all                                   |                       on |          off                         |
#  | MultipartonInteractions:alphaSvalue           |                  0.12700 |      0.13000   0.0600000     0.25000 |
#  | MultipartonInteractions:bProfile              |                        1 |            3           0           4 |
#  | MultipartonInteractions:ecmPow                |                  0.24000 |      0.21500         0.0     0.50000 |
#  | MultipartonInteractions:ecmRef                |                 1800.000 |     7000.000     1.00000             |
#  | MultipartonInteractions:expPow                |                  1.00000 |      1.85000     0.40000    10.00000 |
#  | MultipartonInteractions:pT0Ref                |                  2.25000 |      2.28000     0.50000    10.00000 |
#  | Next:numberCount                              |                        0 |         1000           0             |
#  | Next:numberShowEvent                          |                        0 |            1           0             |
#  | Next:numberShowInfo                           |                        0 |            1           0             |
#  | Next:numberShowLHA                            |                        0 |            1           0             |
#  | Next:numberShowProcess                        |                        0 |            1           0             |
#  | PDF:pSet                                      |                        2 |           13                         |
#  | SigmaDiffractive:dampen                       |                      off |           on                         |
#  | SigmaProcess:alphaSvalue                      |                  0.12650 |      0.13000   0.0600000     0.25000 |
#  | SpaceShower:alphaSvalue                       |                  0.13700 |      0.13650   0.0600000     0.25000 |
#  | SpaceShower:ecmRef                            |                 1800.000 |     7000.000     1.00000             |
#  | SpaceShower:phiIntAsym                        |                      off |           on                         |
#  | SpaceShower:phiPolAsym                        |                      off |           on                         |
#  | SpaceShower:rapidityOrder                     |                      off |           on                         |
#  | SpaceShower:rapidityOrderMPI                  |                      off |           on                         |
#  | StringFlav:etaSup                             |                  0.63000 |      0.60000         0.0     1.00000 |
#  | StringFlav:mesonBvector                       |                  3.00000 |      2.20000         0.0     3.00000 |
#  | StringFlav:mesonCvector                       |                  1.06000 |      0.88000         0.0     3.00000 |
#  | StringFlav:mesonSvector                       |                  0.72500 |      0.55000         0.0     3.00000 |
#  | StringFlav:mesonUDvector                      |                  0.62000 |      0.50000         0.0     3.00000 |
#  | StringFlav:popcornSpair                       |                  0.50000 |      0.90000         0.0     1.00000 |
#  | StringFlav:probQQ1toQQ0                       |                0.0270000 |    0.0275000         0.0     1.00000 |
#  | StringFlav:probQQtoQ                          |                0.0900000 |    0.0810000         0.0     1.00000 |
#  | StringFlav:probSQtoQQ                         |                  1.00000 |      0.91500         0.0     1.00000 |
#  | StringFlav:probStoUD                          |                  0.19000 |      0.21700         0.0     1.00000 |
#  | StringPT:sigma                                |                  0.30400 |      0.33500         0.0     1.00000 |
#  | StringZ:aExtraDiquark                         |                  0.50000 |      0.97000         0.0     2.00000 |
#  | StringZ:aLund                                 |                  0.30000 |      0.68000         0.0     2.00000 |
#  | StringZ:bLund                                 |                  0.80000 |      0.98000     0.20000     2.00000 |
#  | StringZ:rFactB                                |                  0.67000 |      0.85500         0.0     2.00000 |
#  | StringZ:rFactC                                |                  1.00000 |      1.32000         0.0     2.00000 |
#  | TimeShower:alphaSvalue                        |                  0.13830 |      0.13650   0.0600000     0.25000 |
#  | TimeShower:dampenBeamRecoil                   |                      off |           on                         |
#  | TimeShower:phiPolAsym                         |                      off |           on                         |
#  | TimeShower:pTmin                              |                  0.40000 |      0.50000     0.10000     2.00000 |
#  | TimeShower:pTminChgQ                          |                  0.40000 |      0.50000     0.10000     2.00000 |
#  | Tune:ee                                       |                        3 |            7          -1           7 |
#  | Tune:pp                                       |                        2 |           14          -1          34 |
#  |                                                                                                                 |
#  *-------  End PYTHIA Flag + Mode + Parm + Word + FVec + MVec + PVec + WVec Settings  -----------------------------*
#
#  --------  PYTHIA Particle Data Table (changed only)  ------------------------------------------------------------------------------
#
#       id   name            antiName         spn chg col      m0        mWidth      mMin       mMax       tau0    res dec ext vis wid
#              no onMode   bRatio   meMode     products
#
#  no particle data has been changed from its default value
#
#  --------  End PYTHIA Particle Data Table  -----------------------------------------------------------------------------------------
#
# Generating a few signal events for signal process (np) to build up statistics
#  Angantyr Info: Initializing minimum bias processes.
#
#  *-------  PYTHIA Process Initialization  --------------------------*
#  |                                                                  |
#  | We collide p+ with p+ at a CM energy of 7.000e+03 GeV            |
#  |                                                                  |
#  |------------------------------------------------------------------|
#  |                                                    |             |
#  | Subprocess                                    Code |   Estimated |
#  |                                                    |    max (mb) |
#  |                                                    |             |
#  |------------------------------------------------------------------|
#  |                                                    |             |
#  | non-diffractive                                101 |   4.812e+01 |
#  | A B -> A B elastic                             102 |   1.970e+01 |
#  | A B -> X B single diffractive                  103 |   6.842e+00 |
#  | A B -> A X single diffractive                  104 |   6.842e+00 |
#  | A B -> X X double diffractive                  105 |   9.259e+00 |
#  | A B -> A X B central diffractive               106 |   0.000e+00 |
#  |                                                                  |
#  *-------  End PYTHIA Process Initialization -----------------------*
#
#  *-------  PYTHIA Multiparton Interactions Initialization  ---------*
#  |                                                                  |
#  |                   sigmaNonDiffractive =    48.12 mb              |
#  |                                                                  |
#  |    pT0 =  3.12 gives sigmaInteraction =   152.10 mb: accepted    |
#  |                                                                  |
#  *-------  End PYTHIA Multiparton Interactions Initialization  -----*
#
#  *-------  PYTHIA Multiparton Interactions Initialization  ---------*
#  |                                                                  |
#  |   diffraction XB for p+ on p+                                    |
#  |                                                                  |
#  |   diffractive mass = 1.00e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  0.65 gives sigmaInteraction =    12.45 mb: accepted    |
#  |   diffractive mass = 1.60e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  0.72 gives sigmaInteraction =    12.70 mb: accepted    |
#  |   diffractive mass = 2.55e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  0.81 gives sigmaInteraction =    12.51 mb: accepted    |
#  |   diffractive mass = 4.07e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  0.91 gives sigmaInteraction =    12.09 mb: accepted    |
#  |   diffractive mass = 6.50e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.01 gives sigmaInteraction =    11.59 mb: accepted    |
#  |   diffractive mass = 1.04e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.13 gives sigmaInteraction =    11.32 mb: accepted    |
#  |   diffractive mass = 1.66e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.27 gives sigmaInteraction =    11.35 mb: accepted    |
#  |   diffractive mass = 2.65e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.42 gives sigmaInteraction =    11.78 mb: accepted    |
#  |   diffractive mass = 4.22e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.59 gives sigmaInteraction =    12.62 mb: accepted    |
#  |   diffractive mass = 6.75e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.78 gives sigmaInteraction =    14.06 mb: accepted    |
#  |   diffractive mass = 1.08e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.99 gives sigmaInteraction =    15.80 mb: accepted    |
#  |   diffractive mass = 1.72e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  2.23 gives sigmaInteraction =    18.07 mb: accepted    |
#  |   diffractive mass = 2.75e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  2.49 gives sigmaInteraction =    20.76 mb: accepted    |
#  |   diffractive mass = 4.38e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  2.79 gives sigmaInteraction =    23.55 mb: accepted    |
#  |   diffractive mass = 7.00e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  3.12 gives sigmaInteraction =    27.78 mb: accepted    |
#  |                                                                  |
#  *-------  End PYTHIA Multiparton Interactions Initialization  -----*
#  PYTHIA Warning in MultipartonInteractions::init: maximum increased by factor 4.834
#
#  *-------  PYTHIA Multiparton Interactions Initialization  ---------*
#  |                                                                  |
#  |   diffraction AX for p+ on p+                                    |
#  |                                                                  |
#  |   diffractive mass = 1.00e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  0.65 gives sigmaInteraction =    12.36 mb: accepted    |
#  |   diffractive mass = 1.60e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  0.72 gives sigmaInteraction =    12.85 mb: accepted    |
#  |   diffractive mass = 2.55e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  0.81 gives sigmaInteraction =    12.51 mb: accepted    |
#  |   diffractive mass = 4.07e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  0.91 gives sigmaInteraction =    12.07 mb: accepted    |
#  |   diffractive mass = 6.50e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.01 gives sigmaInteraction =    11.58 mb: accepted    |
#  |   diffractive mass = 1.04e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.13 gives sigmaInteraction =    11.30 mb: accepted    |
#  |   diffractive mass = 1.66e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.27 gives sigmaInteraction =    11.41 mb: accepted    |
#  |   diffractive mass = 2.65e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.42 gives sigmaInteraction =    11.85 mb: accepted    |
#  |   diffractive mass = 4.22e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.59 gives sigmaInteraction =    12.74 mb: accepted    |
#  |   diffractive mass = 6.75e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.78 gives sigmaInteraction =    14.14 mb: accepted    |
#  |   diffractive mass = 1.08e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.99 gives sigmaInteraction =    15.93 mb: accepted    |
#  |   diffractive mass = 1.72e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  2.23 gives sigmaInteraction =    17.97 mb: accepted    |
#  |   diffractive mass = 2.75e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  2.49 gives sigmaInteraction =    20.71 mb: accepted    |
#  |   diffractive mass = 4.38e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  2.79 gives sigmaInteraction =    23.82 mb: accepted    |
#  |   diffractive mass = 7.00e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  3.12 gives sigmaInteraction =    27.55 mb: accepted    |
#  |                                                                  |
#  *-------  End PYTHIA Multiparton Interactions Initialization  -----*
#
#  *-------  PYTHIA Multiparton Interactions Initialization  ---------*
#  |                                                                  |
#  |   diffraction AXB for p+ on p+                                   |
#  |                                                                  |
#  |   diffractive mass = 1.00e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  0.65 gives sigmaInteraction =     2.74 mb: rejected    |
#  |    pT0 =  0.58 gives sigmaInteraction =     4.02 mb: rejected    |
#  |    pT0 =  0.52 gives sigmaInteraction =     5.85 mb: rejected    |
#  |    pT0 =  0.47 gives sigmaInteraction =     8.54 mb: rejected    |
#  |    pT0 =  0.42 gives sigmaInteraction =    12.35 mb: accepted    |
#  |   diffractive mass = 1.60e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  0.72 gives sigmaInteraction =     2.27 mb: rejected    |
#  |    pT0 =  0.65 gives sigmaInteraction =     3.24 mb: rejected    |
#  |    pT0 =  0.59 gives sigmaInteraction =     4.63 mb: rejected    |
#  |    pT0 =  0.53 gives sigmaInteraction =     6.68 mb: rejected    |
#  |    pT0 =  0.47 gives sigmaInteraction =     9.62 mb: rejected    |
#  |    pT0 =  0.43 gives sigmaInteraction =    13.92 mb: accepted    |
#  |   diffractive mass = 2.55e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  0.81 gives sigmaInteraction =     1.85 mb: rejected    |
#  |    pT0 =  0.73 gives sigmaInteraction =     2.59 mb: rejected    |
#  |    pT0 =  0.66 gives sigmaInteraction =     3.66 mb: rejected    |
#  |    pT0 =  0.59 gives sigmaInteraction =     5.16 mb: rejected    |
#  |    pT0 =  0.53 gives sigmaInteraction =     7.27 mb: rejected    |
#  |    pT0 =  0.48 gives sigmaInteraction =    10.30 mb: rejected    |
#  |    pT0 =  0.43 gives sigmaInteraction =    14.64 mb: accepted    |
#  |   diffractive mass = 4.07e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  0.91 gives sigmaInteraction =     1.58 mb: rejected    |
#  |    pT0 =  0.82 gives sigmaInteraction =     2.14 mb: rejected    |
#  |    pT0 =  0.73 gives sigmaInteraction =     2.92 mb: rejected    |
#  |    pT0 =  0.66 gives sigmaInteraction =     4.01 mb: rejected    |
#  |    pT0 =  0.59 gives sigmaInteraction =     5.54 mb: rejected    |
#  |    pT0 =  0.54 gives sigmaInteraction =     7.68 mb: rejected    |
#  |    pT0 =  0.48 gives sigmaInteraction =    10.84 mb: rejected    |
#  |    pT0 =  0.43 gives sigmaInteraction =    15.29 mb: accepted    |
#  |   diffractive mass = 6.50e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.01 gives sigmaInteraction =     1.41 mb: rejected    |
#  |    pT0 =  0.91 gives sigmaInteraction =     1.84 mb: rejected    |
#  |    pT0 =  0.82 gives sigmaInteraction =     2.44 mb: rejected    |
#  |    pT0 =  0.74 gives sigmaInteraction =     3.24 mb: rejected    |
#  |    pT0 =  0.67 gives sigmaInteraction =     4.42 mb: rejected    |
#  |    pT0 =  0.60 gives sigmaInteraction =     5.88 mb: rejected    |
#  |    pT0 =  0.54 gives sigmaInteraction =     8.13 mb: rejected    |
#  |    pT0 =  0.48 gives sigmaInteraction =    11.26 mb: accepted    |
#  |   diffractive mass = 1.04e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.13 gives sigmaInteraction =     1.37 mb: rejected    |
#  |    pT0 =  1.02 gives sigmaInteraction =     1.75 mb: rejected    |
#  |    pT0 =  0.92 gives sigmaInteraction =     2.21 mb: rejected    |
#  |    pT0 =  0.83 gives sigmaInteraction =     2.84 mb: rejected    |
#  |    pT0 =  0.74 gives sigmaInteraction =     3.69 mb: rejected    |
#  |    pT0 =  0.67 gives sigmaInteraction =     4.79 mb: rejected    |
#  |    pT0 =  0.60 gives sigmaInteraction =     6.31 mb: rejected    |
#  |    pT0 =  0.54 gives sigmaInteraction =     8.63 mb: rejected    |
#  |    pT0 =  0.49 gives sigmaInteraction =    11.59 mb: accepted    |
#  |   diffractive mass = 1.66e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.27 gives sigmaInteraction =     1.44 mb: rejected    |
#  |    pT0 =  1.14 gives sigmaInteraction =     1.76 mb: rejected    |
#  |    pT0 =  1.03 gives sigmaInteraction =     2.17 mb: rejected    |
#  |    pT0 =  0.93 gives sigmaInteraction =     2.72 mb: rejected    |
#  |    pT0 =  0.83 gives sigmaInteraction =     3.38 mb: rejected    |
#  |    pT0 =  0.75 gives sigmaInteraction =     4.25 mb: rejected    |
#  |    pT0 =  0.67 gives sigmaInteraction =     5.42 mb: rejected    |
#  |    pT0 =  0.61 gives sigmaInteraction =     6.96 mb: rejected    |
#  |    pT0 =  0.55 gives sigmaInteraction =     9.16 mb: rejected    |
#  |    pT0 =  0.49 gives sigmaInteraction =    12.14 mb: accepted    |
#  |   diffractive mass = 2.65e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.42 gives sigmaInteraction =     1.59 mb: rejected    |
#  |    pT0 =  1.28 gives sigmaInteraction =     1.92 mb: rejected    |
#  |    pT0 =  1.15 gives sigmaInteraction =     2.30 mb: rejected    |
#  |    pT0 =  1.04 gives sigmaInteraction =     2.78 mb: rejected    |
#  |    pT0 =  0.93 gives sigmaInteraction =     3.35 mb: rejected    |
#  |    pT0 =  0.84 gives sigmaInteraction =     4.05 mb: rejected    |
#  |    pT0 =  0.75 gives sigmaInteraction =     5.01 mb: rejected    |
#  |    pT0 =  0.68 gives sigmaInteraction =     6.13 mb: rejected    |
#  |    pT0 =  0.61 gives sigmaInteraction =     7.73 mb: rejected    |
#  |    pT0 =  0.55 gives sigmaInteraction =     9.89 mb: rejected    |
#  |    pT0 =  0.50 gives sigmaInteraction =    12.89 mb: accepted    |
#  |   diffractive mass = 4.22e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.59 gives sigmaInteraction =     1.78 mb: rejected    |
#  |    pT0 =  1.43 gives sigmaInteraction =     2.13 mb: rejected    |
#  |    pT0 =  1.29 gives sigmaInteraction =     2.57 mb: rejected    |
#  |    pT0 =  1.16 gives sigmaInteraction =     3.03 mb: rejected    |
#  |    pT0 =  1.04 gives sigmaInteraction =     3.57 mb: rejected    |
#  |    pT0 =  0.94 gives sigmaInteraction =     4.21 mb: rejected    |
#  |    pT0 =  0.84 gives sigmaInteraction =     5.00 mb: rejected    |
#  |    pT0 =  0.76 gives sigmaInteraction =     5.98 mb: rejected    |
#  |    pT0 =  0.68 gives sigmaInteraction =     7.15 mb: rejected    |
#  |    pT0 =  0.62 gives sigmaInteraction =     8.95 mb: rejected    |
#  |    pT0 =  0.55 gives sigmaInteraction =    11.02 mb: accepted    |
#  |   diffractive mass = 6.75e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.78 gives sigmaInteraction =     2.05 mb: rejected    |
#  |    pT0 =  1.60 gives sigmaInteraction =     2.44 mb: rejected    |
#  |    pT0 =  1.44 gives sigmaInteraction =     2.89 mb: rejected    |
#  |    pT0 =  1.30 gives sigmaInteraction =     3.36 mb: rejected    |
#  |    pT0 =  1.17 gives sigmaInteraction =     3.97 mb: rejected    |
#  |    pT0 =  1.05 gives sigmaInteraction =     4.58 mb: rejected    |
#  |    pT0 =  0.94 gives sigmaInteraction =     5.32 mb: rejected    |
#  |    pT0 =  0.85 gives sigmaInteraction =     6.23 mb: rejected    |
#  |    pT0 =  0.77 gives sigmaInteraction =     7.24 mb: rejected    |
#  |    pT0 =  0.69 gives sigmaInteraction =     8.48 mb: rejected    |
#  |    pT0 =  0.62 gives sigmaInteraction =    10.27 mb: rejected    |
#  |    pT0 =  0.56 gives sigmaInteraction =    12.39 mb: accepted    |
#  |   diffractive mass = 1.08e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.99 gives sigmaInteraction =     2.31 mb: rejected    |
#  |    pT0 =  1.79 gives sigmaInteraction =     2.77 mb: rejected    |
#  |    pT0 =  1.61 gives sigmaInteraction =     3.26 mb: rejected    |
#  |    pT0 =  1.45 gives sigmaInteraction =     3.82 mb: rejected    |
#  |    pT0 =  1.31 gives sigmaInteraction =     4.42 mb: rejected    |
#  |    pT0 =  1.17 gives sigmaInteraction =     5.15 mb: rejected    |
#  |    pT0 =  1.06 gives sigmaInteraction =     5.91 mb: rejected    |
#  |    pT0 =  0.95 gives sigmaInteraction =     6.72 mb: rejected    |
#  |    pT0 =  0.86 gives sigmaInteraction =     7.81 mb: rejected    |
#  |    pT0 =  0.77 gives sigmaInteraction =     8.79 mb: rejected    |
#  |    pT0 =  0.69 gives sigmaInteraction =    10.12 mb: rejected    |
#  |    pT0 =  0.62 gives sigmaInteraction =    11.91 mb: accepted    |
#  |   diffractive mass = 1.72e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  2.23 gives sigmaInteraction =     2.62 mb: rejected    |
#  |    pT0 =  2.00 gives sigmaInteraction =     3.14 mb: rejected    |
#  |    pT0 =  1.80 gives sigmaInteraction =     3.71 mb: rejected    |
#  |    pT0 =  1.62 gives sigmaInteraction =     4.34 mb: rejected    |
#  |    pT0 =  1.46 gives sigmaInteraction =     5.03 mb: rejected    |
#  |    pT0 =  1.31 gives sigmaInteraction =     5.77 mb: rejected    |
#  |    pT0 =  1.18 gives sigmaInteraction =     6.63 mb: rejected    |
#  |    pT0 =  1.06 gives sigmaInteraction =     7.47 mb: rejected    |
#  |    pT0 =  0.96 gives sigmaInteraction =     8.51 mb: rejected    |
#  |    pT0 =  0.86 gives sigmaInteraction =     9.61 mb: rejected    |
#  |    pT0 =  0.78 gives sigmaInteraction =    10.69 mb: rejected    |
#  |    pT0 =  0.70 gives sigmaInteraction =    12.20 mb: accepted    |
#  |   diffractive mass = 2.75e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  2.49 gives sigmaInteraction =     2.90 mb: rejected    |
#  |    pT0 =  2.24 gives sigmaInteraction =     3.48 mb: rejected    |
#  |    pT0 =  2.02 gives sigmaInteraction =     4.12 mb: rejected    |
#  |    pT0 =  1.82 gives sigmaInteraction =     4.84 mb: rejected    |
#  |    pT0 =  1.63 gives sigmaInteraction =     5.65 mb: rejected    |
#  |    pT0 =  1.47 gives sigmaInteraction =     6.47 mb: rejected    |
#  |    pT0 =  1.32 gives sigmaInteraction =     7.42 mb: rejected    |
#  |    pT0 =  1.19 gives sigmaInteraction =     8.46 mb: rejected    |
#  |    pT0 =  1.07 gives sigmaInteraction =     9.48 mb: rejected    |
#  |    pT0 =  0.96 gives sigmaInteraction =    10.54 mb: rejected    |
#  |    pT0 =  0.87 gives sigmaInteraction =    11.84 mb: accepted    |
#  |   diffractive mass = 4.38e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  2.79 gives sigmaInteraction =     3.20 mb: rejected    |
#  |    pT0 =  2.51 gives sigmaInteraction =     3.91 mb: rejected    |
#  |    pT0 =  2.26 gives sigmaInteraction =     4.62 mb: rejected    |
#  |    pT0 =  2.03 gives sigmaInteraction =     5.35 mb: rejected    |
#  |    pT0 =  1.83 gives sigmaInteraction =     6.30 mb: rejected    |
#  |    pT0 =  1.65 gives sigmaInteraction =     7.30 mb: rejected    |
#  |    pT0 =  1.48 gives sigmaInteraction =     8.26 mb: rejected    |
#  |    pT0 =  1.33 gives sigmaInteraction =     9.33 mb: rejected    |
#  |    pT0 =  1.20 gives sigmaInteraction =    10.59 mb: rejected    |
#  |    pT0 =  1.08 gives sigmaInteraction =    11.81 mb: accepted    |
#  |   diffractive mass = 7.00e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  3.12 gives sigmaInteraction =     3.50 mb: rejected    |
#  |    pT0 =  2.81 gives sigmaInteraction =     4.21 mb: rejected    |
#  |    pT0 =  2.52 gives sigmaInteraction =     4.95 mb: rejected    |
#  |    pT0 =  2.27 gives sigmaInteraction =     5.93 mb: rejected    |
#  |    pT0 =  2.05 gives sigmaInteraction =     6.93 mb: rejected    |
#  |    pT0 =  1.84 gives sigmaInteraction =     7.96 mb: rejected    |
#  |    pT0 =  1.66 gives sigmaInteraction =     9.13 mb: rejected    |
#  |    pT0 =  1.49 gives sigmaInteraction =    10.52 mb: rejected    |
#  |    pT0 =  1.34 gives sigmaInteraction =    11.79 mb: accepted    |
#  |                                                                  |
#  *-------  End PYTHIA Multiparton Interactions Initialization  -----*
#
#  *-------  PYTHIA Flag + Mode + Parm + Word + FVec + MVec + PVec + WVec Settings (changes only)  ------------------*
#  |                                                                                                                 |
#  | Name                                          |                      Now |      Default         Min         Max |
#  |                                               |                          |                                      |
#  | BeamRemnants:halfScaleForKT                   |                  1.00000 |      1.50000         0.0             |
#  | BeamRemnants:primordialKThard                 |                  2.00000 |      1.80000         0.0             |
#  | BeamRemnants:primordialKTsoft                 |                  0.50000 |      0.90000         0.0             |
#  | Beams:eCM                                     |                 7000.000 |    14000.000         0.0             |
#  | ColourReconnection:range                      |                 10.00000 |      1.80000         0.0    10.00000 |
#  | Diffraction:largeMassSuppress                 |                  2.00000 |      4.00000         0.0             |
#  | HadronLevel:all                               |                      off |           on                         |
#  | MultipartonInteractions:alphaSvalue           |                  0.12700 |      0.13000   0.0600000     0.25000 |
#  | MultipartonInteractions:bProfile              |                        1 |            3           0           4 |
#  | MultipartonInteractions:ecmPow                |                  0.24000 |      0.21500         0.0     0.50000 |
#  | MultipartonInteractions:ecmRef                |                 1800.000 |     7000.000     1.00000             |
#  | MultipartonInteractions:expPow                |                  1.00000 |      1.85000     0.40000    10.00000 |
#  | MultipartonInteractions:pT0Ref                |                  2.25000 |      2.28000     0.50000    10.00000 |
#  | Next:numberCount                              |                        0 |         1000           0             |
#  | Next:numberShowEvent                          |                        0 |            1           0             |
#  | Next:numberShowInfo                           |                        0 |            1           0             |
#  | Next:numberShowLHA                            |                        0 |            1           0             |
#  | Next:numberShowProcess                        |                        0 |            1           0             |
#  | PDF:pSet                                      |                        2 |           13                         |
#  | SigmaDiffractive:dampen                       |                      off |           on                         |
#  | SigmaProcess:alphaSvalue                      |                  0.12650 |      0.13000   0.0600000     0.25000 |
#  | SoftQCD:all                                   |                       on |          off                         |
#  | SpaceShower:alphaSvalue                       |                  0.13700 |      0.13650   0.0600000     0.25000 |
#  | SpaceShower:ecmRef                            |                 1800.000 |     7000.000     1.00000             |
#  | SpaceShower:phiIntAsym                        |                      off |           on                         |
#  | SpaceShower:phiPolAsym                        |                      off |           on                         |
#  | SpaceShower:rapidityOrder                     |                      off |           on                         |
#  | SpaceShower:rapidityOrderMPI                  |                      off |           on                         |
#  | StringFlav:etaSup                             |                  0.63000 |      0.60000         0.0     1.00000 |
# ...
#  |    pT0 =  2.28 gives sigmaInteraction =    30.41 mb: rejected    |
#  |    pT0 =  2.05 gives sigmaInteraction =    45.68 mb: rejected    |
#  |    pT0 =  1.85 gives sigmaInteraction =    68.27 mb: accepted    |
#  |   diffractive mass = 4.07e+01 GeV and sigmaNorm =    48.12 mb    |
#  |    pT0 =  2.28 gives sigmaInteraction =    39.63 mb: rejected    |
#  |    pT0 =  2.05 gives sigmaInteraction =    57.23 mb: accepted    |
#  |   diffractive mass = 6.50e+01 GeV and sigmaNorm =    48.12 mb    |
#  |    pT0 =  2.28 gives sigmaInteraction =    51.67 mb: rejected    |
#  |    pT0 =  2.05 gives sigmaInteraction =    72.43 mb: accepted    |
#  |   diffractive mass = 1.04e+02 GeV and sigmaNorm =    48.12 mb    |
#  |    pT0 =  2.28 gives sigmaInteraction =    67.56 mb: accepted    |
#  |   diffractive mass = 1.66e+02 GeV and sigmaNorm =    48.12 mb    |
#  |    pT0 =  2.28 gives sigmaInteraction =    85.55 mb: accepted    |
#  |   diffractive mass = 2.65e+02 GeV and sigmaNorm =    48.12 mb    |
#  |    pT0 =  2.28 gives sigmaInteraction =   106.69 mb: accepted    |
#  |   diffractive mass = 4.22e+02 GeV and sigmaNorm =    48.12 mb    |
#  |    pT0 =  2.28 gives sigmaInteraction =   128.78 mb: accepted    |
#  |   diffractive mass = 6.75e+02 GeV and sigmaNorm =    48.12 mb    |
#  |    pT0 =  2.28 gives sigmaInteraction =   153.46 mb: accepted    |
#  |   diffractive mass = 1.08e+03 GeV and sigmaNorm =    48.12 mb    |
#  |    pT0 =  2.28 gives sigmaInteraction =   174.76 mb: accepted    |
#  |   diffractive mass = 1.72e+03 GeV and sigmaNorm =    48.12 mb    |
#  |    pT0 =  2.28 gives sigmaInteraction =   196.48 mb: accepted    |
#  |   diffractive mass = 2.75e+03 GeV and sigmaNorm =    48.12 mb    |
#  |    pT0 =  2.28 gives sigmaInteraction =   211.55 mb: accepted    |
#  |   diffractive mass = 4.38e+03 GeV and sigmaNorm =    48.12 mb    |
#  |    pT0 =  2.28 gives sigmaInteraction =   225.27 mb: accepted    |
#  |   diffractive mass = 7.00e+03 GeV and sigmaNorm =    48.12 mb    |
#  |    pT0 =  2.28 gives sigmaInteraction =   226.09 mb: accepted    |
#  |                                                                  |
#  *-------  End PYTHIA Multiparton Interactions Initialization  -----*
#
#  *-------  PYTHIA Flag + Mode + Parm + Word + FVec + MVec + PVec + WVec Settings (changes only)  ------------------*
#  |                                                                                                                 |
#  | Name                                          |                      Now |      Default         Min         Max |
#  |                                               |                          |                                      |
#  | Beams:eCM                                     |                 7000.000 |    14000.000         0.0             |
#  | ColourReconnection:range                      |                 10.00000 |      1.80000         0.0    10.00000 |
#  | Diffraction:mRefPomP                          |                 7000.000 |    100.00000     1.00000             |
#  | Diffraction:sigmaRefPomP                      |                 48.12128 |     10.00000     2.00000    40.00000 |
#  | HadronLevel:all                               |                      off |           on                         |
#  | MultipartonInteractions:ecmPow                |                      0.0 |      0.21500         0.0     0.50000 |
#  | Next:numberCount                              |                        0 |         1000           0             |
#  | Next:numberShowEvent                          |                        0 |            1           0             |
#  | Next:numberShowInfo                           |                        0 |            1           0             |
#  | Next:numberShowLHA                            |                        0 |            1           0             |
#  | Next:numberShowProcess                        |                        0 |            1           0             |
#  | PDF:PomSet                                    |                       11 |            6                         |
#  | SigmaProcess:alphaSvalue                      |                  0.12650 |      0.13000   0.0600000     0.25000 |
#  | SoftQCD:singleDiffractive                     |                       on |          off                         |
#  | SpaceShower:alphaSvalue                       |                  0.13700 |      0.13650   0.0600000     0.25000 |
#  | SpaceShower:ecmRef                            |                 1800.000 |     7000.000     1.00000             |
#  | SpaceShower:phiIntAsym                        |                      off |           on                         |
#  | SpaceShower:phiPolAsym                        |                      off |           on                         |
#  | SpaceShower:rapidityOrder                     |                      off |           on                         |
#  | SpaceShower:rapidityOrderMPI                  |                      off |           on                         |
#  | StringFlav:etaSup                             |                  0.63000 |      0.60000         0.0     1.00000 |
#  | StringFlav:mesonBvector                       |                  3.00000 |      2.20000         0.0     3.00000 |
#  | StringFlav:mesonCvector                       |                  1.06000 |      0.88000         0.0     3.00000 |
#  | StringFlav:mesonSvector                       |                  0.72500 |      0.55000         0.0     3.00000 |
#  | StringFlav:mesonUDvector                      |                  0.62000 |      0.50000         0.0     3.00000 |
#  | StringFlav:popcornSpair                       |                  0.50000 |      0.90000         0.0     1.00000 |
#  | StringFlav:probQQ1toQQ0                       |                0.0270000 |    0.0275000         0.0     1.00000 |
#  | StringFlav:probQQtoQ                          |                0.0900000 |    0.0810000         0.0     1.00000 |
#  | StringFlav:probSQtoQQ                         |                  1.00000 |      0.91500         0.0     1.00000 |
#  | StringFlav:probStoUD                          |                  0.19000 |      0.21700         0.0     1.00000 |
#  | StringPT:sigma                                |                  0.30400 |      0.33500         0.0     1.00000 |
#  | StringZ:aExtraDiquark                         |                  0.50000 |      0.97000         0.0     2.00000 |
#  | StringZ:aLund                                 |                  0.30000 |      0.68000         0.0     2.00000 |
#  | StringZ:bLund                                 |                  0.80000 |      0.98000     0.20000     2.00000 |
#  | StringZ:rFactB                                |                  0.67000 |      0.85500         0.0     2.00000 |
#  | StringZ:rFactC                                |                  1.00000 |      1.32000         0.0     2.00000 |
#  | TimeShower:alphaSvalue                        |                  0.13830 |      0.13650   0.0600000     0.25000 |
#  | TimeShower:dampenBeamRecoil                   |                      off |           on                         |
#  | TimeShower:phiPolAsym                         |                      off |           on                         |
#  | TimeShower:pTmin                              |                  0.40000 |      0.50000     0.10000     2.00000 |
#  | TimeShower:pTminChgQ                          |                  0.40000 |      0.50000     0.10000     2.00000 |
#  | Tune:ee                                       |                        0 |            7          -1           7 |
#  | Tune:pp                                       |                        0 |           14          -1          34 |
#  |                                                                                                                 |
#  *-------  End PYTHIA Flag + Mode + Parm + Word + FVec + MVec + PVec + WVec Settings  -----------------------------*
#
#  --------  PYTHIA Particle Data Table (changed only)  ------------------------------------------------------------------------------
#
#       id   name            antiName         spn chg col      m0        mWidth      mMin       mMax       tau0    res dec ext vis wid
#              no onMode   bRatio   meMode     products
#
#  no particle data has been changed from its default value
#
#  --------  End PYTHIA Particle Data Table  -----------------------------------------------------------------------------------------
#
#  Angantyr Info: Initializing hadronisation processes.
#
#  *-------  PYTHIA Flag + Mode + Parm + Word + FVec + MVec + PVec + WVec Settings (changes only)  ------------------*
#  |                                                                                                                 |
#  | Name                                          |                      Now |      Default         Min         Max |
#  |                                               |                          |                                      |
#  | BeamRemnants:halfScaleForKT                   |                  1.00000 |      1.50000         0.0             |
#  | BeamRemnants:primordialKThard                 |                  2.00000 |      1.80000         0.0             |
#  | BeamRemnants:primordialKTsoft                 |                  0.50000 |      0.90000         0.0             |
#  | Beams:eCM                                     |                 7000.000 |    14000.000         0.0             |
#  | Beams:idA                                     |               1000822080 |         2212                         |
#  | ColourReconnection:range                      |                 10.00000 |      1.80000         0.0    10.00000 |
#  | Diffraction:largeMassSuppress                 |                  2.00000 |      4.00000         0.0             |
#  | MultipartonInteractions:alphaSvalue           |                  0.12700 |      0.13000   0.0600000     0.25000 |
#  | MultipartonInteractions:bProfile              |                        1 |            3           0           4 |
#  | MultipartonInteractions:ecmPow                |                  0.24000 |      0.21500         0.0     0.50000 |
#  | MultipartonInteractions:ecmRef                |                 1800.000 |     7000.000     1.00000             |
#  | MultipartonInteractions:expPow                |                  1.00000 |      1.85000     0.40000    10.00000 |
#  | MultipartonInteractions:pT0Ref                |                  2.25000 |      2.28000     0.50000    10.00000 |
#  | Next:numberCount                              |                        0 |         1000           0             |
#  | Next:numberShowEvent                          |                        0 |            1           0             |
#  | Next:numberShowInfo                           |                        0 |            1           0             |
#  | Next:numberShowLHA                            |                        0 |            1           0             |
#  | Next:numberShowProcess                        |                        0 |            1           0             |
#  | PartonLevel:all                               |                      off |           on                         |
#  | PDF:pSet                                      |                        2 |           13                         |
#  | ProcessLevel:all                              |                      off |           on                         |
#  | SigmaDiffractive:dampen                       |                      off |           on                         |
#  | SigmaProcess:alphaSvalue                      |                  0.12650 |      0.13000   0.0600000     0.25000 |
#  | SpaceShower:alphaSvalue                       |                  0.13700 |      0.13650   0.0600000     0.25000 |
#  | SpaceShower:ecmRef                            |                 1800.000 |     7000.000     1.00000             |
#  | SpaceShower:phiIntAsym                        |                      off |           on                         |
#  | SpaceShower:phiPolAsym                        |                      off |           on                         |
#  | SpaceShower:rapidityOrder                     |                      off |           on                         |
#  | SpaceShower:rapidityOrderMPI                  |                      off |           on                         |
#  | StringFlav:etaSup                             |                  0.63000 |      0.60000         0.0     1.00000 |
#  | StringFlav:mesonBvector                       |                  3.00000 |      2.20000         0.0     3.00000 |
#  | StringFlav:mesonCvector                       |                  1.06000 |      0.88000         0.0     3.00000 |
#  | StringFlav:mesonSvector                       |                  0.72500 |      0.55000         0.0     3.00000 |
#  | StringFlav:mesonUDvector                      |                  0.62000 |      0.50000         0.0     3.00000 |
#  | StringFlav:popcornSpair                       |                  0.50000 |      0.90000         0.0     1.00000 |
#  | StringFlav:probQQ1toQQ0                       |                0.0270000 |    0.0275000         0.0     1.00000 |
#  | StringFlav:probQQtoQ                          |                0.0900000 |    0.0810000         0.0     1.00000 |
#  | StringFlav:probSQtoQQ                         |                  1.00000 |      0.91500         0.0     1.00000 |
#  | StringFlav:probStoUD                          |                  0.19000 |      0.21700         0.0     1.00000 |
#  | StringPT:sigma                                |                  0.30400 |      0.33500         0.0     1.00000 |
#  | StringZ:aExtraDiquark                         |                  0.50000 |      0.97000         0.0     2.00000 |
#  | StringZ:aLund                                 |                  0.30000 |      0.68000         0.0     2.00000 |
#  | StringZ:bLund                                 |                  0.80000 |      0.98000     0.20000     2.00000 |
#  | StringZ:rFactB                                |                  0.67000 |      0.85500         0.0     2.00000 |
#  | StringZ:rFactC                                |                  1.00000 |      1.32000         0.0     2.00000 |
#  | TimeShower:alphaSvalue                        |                  0.13830 |      0.13650   0.0600000     0.25000 |
#  | TimeShower:dampenBeamRecoil                   |                      off |           on                         |
#  | TimeShower:phiPolAsym                         |                      off |           on                         |
#  | TimeShower:pTmin                              |                  0.40000 |      0.50000     0.10000     2.00000 |
#  | TimeShower:pTminChgQ                          |                  0.40000 |      0.50000     0.10000     2.00000 |
#  | Tune:ee                                       |                        0 |            7          -1           7 |
#  | Tune:pp                                       |                        0 |           14          -1          34 |
#  |                                                                                                                 |
#  *-------  End PYTHIA Flag + Mode + Parm + Word + FVec + MVec + PVec + WVec Settings  -----------------------------*
#
#  --------  PYTHIA Particle Data Table (changed only)  ------------------------------------------------------------------------------
#
#       id   name            antiName         spn chg col      m0        mWidth      mMin       mMax       tau0    res dec ext vis wid
#              no onMode   bRatio   meMode     products
#
#  no particle data has been changed from its default value
#
#  --------  End PYTHIA Particle Data Table  -----------------------------------------------------------------------------------------
#
#  PYTHIA Warning in SimpleSpaceShower::pT2nextQCD: weight above unity

# %%
# Pythia8 Setup
pythia = pythia8.Pythia()


pythia.readString("Beams:eCM = 7000.")
pythia.readString("HardQCD:all = on")  # Enable hard QCD processes to study jets


pythia.readString("Beams:idA = 1000822080; Beams:idB = 1000822080")  # lead ions
pythia.readString("ParticleDecays:limitTau0 = on")  # Decay all unstable particles
pythia.readString("Tune:pp = 2")  # Monash tune for pp collisions (adapt for Au+Au)
pythia.init()

# Event loop
events = 100  # Number of events to simulate
file = ROOT.TFile("alice_tree_7.root", "RECREATE")  # Create a ROOT file
tree = ROOT.TTree("alice_tree_7", "ALICE_pdpd_7_TeV")

# Create vectors for particle properties
px, py, pz, pt, eta, phi, pid = ROOT.std.vector("double")(), ROOT.std.vector("double")(), ROOT.std.vector("double")(), ROOT.std.vector("double")(), ROOT.std.vector("double")(), ROOT.std.vector("double")(), ROOT.std.vector("int")()

# Create branches by linking them with the vectors
tree.Branch("px", px)
tree.Branch("py", py)
tree.Branch("pz", pz)
tree.Branch("pt", pt)
tree.Branch("eta", eta)
tree.Branch("phi", phi)
tree.Branch("pid", pid)

for i in range(events):
    if not pythia.next(): break  # Check for errors

    # Collect particle information
    for particle in pythia.event:
        px.push_back(particle.px())
        py.push_back(particle.py())
        pz.push_back(particle.pz())
        pt.push_back(particle.pT())
        eta.push_back(particle.eta())
        phi.push_back(particle.phi())
        pid.push_back(particle.id())

    # Fill the tree for this event
    tree.Fill()

    # Clear vectors for the next event
    px.clear()
    py.clear()
    pz.clear()
    pt.clear()
    eta.clear()
    phi.clear()
    pid.clear()

# Write to ROOT file and close it
file.Write()
file.Close()

print("ALICE pd+pd simulation complete. Data saved to alice_tree.root")
# Out:
# ALICE pd+pd simulation complete. Data saved to alice_tree.root
#
#  *------------------------------------------------------------------------------------*
#  |                                                                                    |
#  |  *------------------------------------------------------------------------------*  |
#  |  |                                                                              |  |
#  |  |                                                                              |  |
#  |  |   PPP   Y   Y  TTTTT  H   H  III    A      Welcome to the Lund Monte Carlo!  |  |
#  |  |   P  P   Y Y     T    H   H   I    A A     This is PYTHIA version 8.310      |  |
#  |  |   PPP     Y      T    HHHHH   I   AAAAA    Last date of change: 25 Jul 2023  |  |
#  |  |   P       Y      T    H   H   I   A   A                                      |  |
#  |  |   P       Y      T    H   H  III  A   A    Now is 12 Feb 2024 at 14:25:49    |  |
#  |  |                                                                              |  |
#  |  |   Program documentation and an archive of historic versions is found on:     |  |
#  |  |                                                                              |  |
#  |  |                               https://pythia.org/                            |  |
#  |  |                                                                              |  |
#  |  |   PYTHIA is authored by a collaboration consisting of:                       |  |
#  |  |                                                                              |  |
#  |  |   Christian Bierlich, Naomi Cooke, Nishita Desai, Leif Gellersen,            |  |
#  |  |   Ilkka Helenius, Philip Ilten, Leif Lonnblad, Stephen Mrenna,               |  |
#  |  |   Stefan Prestel, Christian Preuss, Torbjorn Sjostrand, Peter Skands,        |  |
#  |  |   Marius Utheim and Rob Verheyen.                                            |  |
#  |  |                                                                              |  |
#  |  |   The complete list of authors, including contact information and            |  |
#  |  |   affiliations, can be found on https://pythia.org/.                         |  |
#  |  |   Problems or bugs should be reported on email at authors@pythia.org.        |  |
#  |  |                                                                              |  |
#  |  |   The main program reference is C. Bierlich et al,                           |  |
#  |  |   'A comprehensive guide to the physics and usage of Pythia 8.3',            |  |
#  |  |   SciPost Phys. Codebases 8-r8.3 (2022) [arXiv:2203.11601 [hep-ph]]          |  |
#  |  |                                                                              |  |
#  |  |   PYTHIA is released under the GNU General Public Licence version 2 or later.|  |
#  |  |   Please respect the MCnet Guidelines for Event Generator Authors and Users. |  |
#  |  |                                                                              |  |
#  |  |   Disclaimer: this program comes without any guarantees.                     |  |
#  |  |   Beware of errors and use common sense when interpreting results.           |  |
#  |  |                                                                              |  |
#  |  |   Copyright (C) 2023 Torbjorn Sjostrand                                      |  |
#  |  |                                                                              |  |
#  |  |                                                                              |  |
#  |  *------------------------------------------------------------------------------*  |
#  |                                                                                    |
#  *------------------------------------------------------------------------------------*
#
#  *----------------------  Initializing Angantyr  ----------------------*
#  |                    We collide: 208Pb on p+                          |
#  |                                                                     |
#  |                    Below follows initialization                     |
#  |                    of sub-collisions.                               |
#  |                                                                     |
#  |                   //>________________________________               |
#  |          [########[]_________________________________>              |
#  |                   \\>                                               |
#  |                                                                     |
#  *------ HeavyIon fitting of SubCollisionModel to cross sections ------*
#  |                                                                     |
#  |   Fitting parameters for   7000.0 GeV                               |
#  |   ....................                                              |
#  |                                                                     |
#  |     Resulting parameters:                                           |
#  |                       [0]:   22.24                                  |
#  |                       [1]:    1.45                                  |
#  |                       [2]:    0.15                                  |
#  |                                                                     |
#  |     Resulting cross sections        (target value)                  |
#  |                    Total:    90.75 *( 90.76 +-  2%) mb              |
#  |          non-diffractive:    48.02 *( 48.12 +-  2%) mb              |
#  |           XX diffractive:     8.90 *(  9.26 +- 10%) mb              |
#  |       wounded target (B):    64.24 *( 64.22 +-  5%) mb              |
#  |   wounded projectile (A):    64.19 *( 64.22 +-  5%) mb              |
#  |          AXB diffractive:     0.00  (  0.00       ) mb              |
#  |                  elastic:    19.23 *( 19.70 +- 10%) mb              |
#  |          elastic b-slope:    27.05  ( 21.73       ) GeV^-2          |
#  |                                                                     |
#  |                 Chi2/Ndf:     0.07                                  |
#  |                                                                     |
#  *--- End HeavyIon fitting of parameters in nucleon collision model ---*
#
#  To avoid refitting, add the following lines to your configuration file:
#   HeavyIon:SigFitNGen = 0
#   HeavyIon:SigFitDefPar = 22.24,1.45,0.15
#
#  Angantyr Info: Initializing signal process (pp).
#
#  *-------  PYTHIA Process Initialization  --------------------------*
#  |                                                                  |
#  | We collide p+ with p+ at a CM energy of 7.000e+03 GeV            |
#  |                                                                  |
#  |------------------------------------------------------------------|
#  |                                                    |             |
#  | Subprocess                                    Code |   Estimated |
#  |                                                    |    max (mb) |
#  |                                                    |             |
#  |------------------------------------------------------------------|
#  |                                                    |             |
#  | g g -> g g                                     111 |   1.239e+04 |
#  | g g -> q qbar (uds)                            112 |   7.618e+01 |
#  | q g -> q g                                     113 |   4.813e+03 |
#  | q q(bar)' -> q q(bar)'                         114 |   2.353e+02 |
#  | q qbar -> g g                                  115 |   1.180e+00 |
#  | q qbar -> q' qbar' (uds)                       116 |   3.018e-01 |
#  | g g -> c cbar                                  121 |   4.178e+01 |
#  | q qbar -> c cbar                               122 |   1.277e-01 |
#  | g g -> b bbar                                  123 |   1.864e+00 |
#  | q qbar -> b bbar                               124 |   1.388e-02 |
#  |                                                                  |
#  *-------  End PYTHIA Process Initialization -----------------------*
#
#  *-------  PYTHIA Multiparton Interactions Initialization  ---------*
#  |                                                                  |
#  |                   sigmaNonDiffractive =    48.12 mb              |
#  |                                                                  |
#  |    pT0 =  3.12 gives sigmaInteraction =   152.26 mb: accepted    |
#  |                                                                  |
#  *-------  End PYTHIA Multiparton Interactions Initialization  -----*
#
#  *-------  PYTHIA Flag + Mode + Parm + Word + FVec + MVec + PVec + WVec Settings (changes only)  ------------------*
#  |                                                                                                                 |
#  | Name                                          |                      Now |      Default         Min         Max |
#  |                                               |                          |                                      |
#  | BeamRemnants:halfScaleForKT                   |                  1.00000 |      1.50000         0.0             |
#  | BeamRemnants:primordialKThard                 |                  2.00000 |      1.80000         0.0             |
#  | BeamRemnants:primordialKTsoft                 |                  0.50000 |      0.90000         0.0             |
#  | Beams:eCM                                     |                 7000.000 |    14000.000         0.0             |
#  | ColourReconnection:range                      |                 10.00000 |      1.80000         0.0    10.00000 |
#  | Diffraction:largeMassSuppress                 |                  2.00000 |      4.00000         0.0             |
#  | HadronLevel:all                               |                      off |           on                         |
#  | HardQCD:all                                   |                       on |          off                         |
#  | MultipartonInteractions:alphaSvalue           |                  0.12700 |      0.13000   0.0600000     0.25000 |
#  | MultipartonInteractions:bProfile              |                        1 |            3           0           4 |
#  | MultipartonInteractions:ecmPow                |                  0.24000 |      0.21500         0.0     0.50000 |
#  | MultipartonInteractions:ecmRef                |                 1800.000 |     7000.000     1.00000             |
#  | MultipartonInteractions:expPow                |                  1.00000 |      1.85000     0.40000    10.00000 |
#  | MultipartonInteractions:pT0Ref                |                  2.25000 |      2.28000     0.50000    10.00000 |
#  | Next:numberCount                              |                        0 |         1000           0             |
#  | Next:numberShowEvent                          |                        0 |            1           0             |
#  | Next:numberShowInfo                           |                        0 |            1           0             |
#  | Next:numberShowLHA                            |                        0 |            1           0             |
#  | Next:numberShowProcess                        |                        0 |            1           0             |
#  | ParticleDecays:limitTau0                      |                       on |          off                         |
#  | PDF:pSet                                      |                        2 |           13                         |
#  | SigmaDiffractive:dampen                       |                      off |           on                         |
#  | SigmaProcess:alphaSvalue                      |                  0.12650 |      0.13000   0.0600000     0.25000 |
#  | SpaceShower:alphaSvalue                       |                  0.13700 |      0.13650   0.0600000     0.25000 |
#  | SpaceShower:ecmRef                            |                 1800.000 |     7000.000     1.00000             |
#  | SpaceShower:phiIntAsym                        |                      off |           on                         |
#  | SpaceShower:phiPolAsym                        |                      off |           on                         |
#  | SpaceShower:rapidityOrder                     |                      off |           on                         |
#  | SpaceShower:rapidityOrderMPI                  |                      off |           on                         |
#  | StringFlav:etaSup                             |                  0.63000 |      0.60000         0.0     1.00000 |
#  | StringFlav:mesonBvector                       |                  3.00000 |      2.20000         0.0     3.00000 |
#  | StringFlav:mesonCvector                       |                  1.06000 |      0.88000         0.0     3.00000 |
#  | StringFlav:mesonSvector                       |                  0.72500 |      0.55000         0.0     3.00000 |
#  | StringFlav:mesonUDvector                      |                  0.62000 |      0.50000         0.0     3.00000 |
#  | StringFlav:popcornSpair                       |                  0.50000 |      0.90000         0.0     1.00000 |
#  | StringFlav:probQQ1toQQ0                       |                0.0270000 |    0.0275000         0.0     1.00000 |
#  | StringFlav:probQQtoQ                          |                0.0900000 |    0.0810000         0.0     1.00000 |
#  | StringFlav:probSQtoQQ                         |                  1.00000 |      0.91500         0.0     1.00000 |
#  | StringFlav:probStoUD                          |                  0.19000 |      0.21700         0.0     1.00000 |
#  | StringPT:sigma                                |                  0.30400 |      0.33500         0.0     1.00000 |
#  | StringZ:aExtraDiquark                         |                  0.50000 |      0.97000         0.0     2.00000 |
#  | StringZ:aLund                                 |                  0.30000 |      0.68000         0.0     2.00000 |
#  | StringZ:bLund                                 |                  0.80000 |      0.98000     0.20000     2.00000 |
#  | StringZ:rFactB                                |                  0.67000 |      0.85500         0.0     2.00000 |
#  | StringZ:rFactC                                |                  1.00000 |      1.32000         0.0     2.00000 |
#  | TimeShower:alphaSvalue                        |                  0.13830 |      0.13650   0.0600000     0.25000 |
#  | TimeShower:dampenBeamRecoil                   |                      off |           on                         |
#  | TimeShower:phiPolAsym                         |                      off |           on                         |
#  | TimeShower:pTmin                              |                  0.40000 |      0.50000     0.10000     2.00000 |
#  | TimeShower:pTminChgQ                          |                  0.40000 |      0.50000     0.10000     2.00000 |
#  | Tune:ee                                       |                        3 |            7          -1           7 |
#  | Tune:pp                                       |                        2 |           14          -1          34 |
#  |                                                                                                                 |
#  *-------  End PYTHIA Flag + Mode + Parm + Word + FVec + MVec + PVec + WVec Settings  -----------------------------*
#
#  --------  PYTHIA Particle Data Table (changed only)  ------------------------------------------------------------------------------
#
#       id   name            antiName         spn chg col      m0        mWidth      mMin       mMax       tau0    res dec ext vis wid
#              no onMode   bRatio   meMode     products
#
#  no particle data has been changed from its default value
#
#  --------  End PYTHIA Particle Data Table  -----------------------------------------------------------------------------------------
#
# Generating a few signal events for signal process (pp) to build up statistics
#  Angantyr Info: Initializing signal process (np).
#
#  *-------  PYTHIA Process Initialization  --------------------------*
#  |                                                                  |
#  | We collide n0 with p+ at a CM energy of 7.000e+03 GeV            |
#  |                                                                  |
#  |------------------------------------------------------------------|
#  |                                                    |             |
#  | Subprocess                                    Code |   Estimated |
#  |                                                    |    max (mb) |
#  |                                                    |             |
#  |------------------------------------------------------------------|
#  |                                                    |             |
#  | g g -> g g                                     111 |   1.239e+04 |
#  | g g -> q qbar (uds)                            112 |   7.618e+01 |
#  | q g -> q g                                     113 |   4.813e+03 |
#  | q q(bar)' -> q q(bar)'                         114 |   2.350e+02 |
#  | q qbar -> g g                                  115 |   1.182e+00 |
#  | q qbar -> q' qbar' (uds)                       116 |   3.008e-01 |
#  | g g -> c cbar                                  121 |   4.178e+01 |
#  | q qbar -> c cbar                               122 |   1.271e-01 |
#  | g g -> b bbar                                  123 |   1.864e+00 |
#  | q qbar -> b bbar                               124 |   1.388e-02 |
#  |                                                                  |
#  *-------  End PYTHIA Process Initialization -----------------------*
#
#  *-------  PYTHIA Multiparton Interactions Initialization  ---------*
#  |                                                                  |
#  |                   sigmaNonDiffractive =    48.12 mb              |
#  |                                                                  |
#  |    pT0 =  3.12 gives sigmaInteraction =   152.57 mb: accepted    |
#  |                                                                  |
#  *-------  End PYTHIA Multiparton Interactions Initialization  -----*
#
#  *-------  PYTHIA Flag + Mode + Parm + Word + FVec + MVec + PVec + WVec Settings (changes only)  ------------------*
#  |                                                                                                                 |
#  | Name                                          |                      Now |      Default         Min         Max |
#  |                                               |                          |                                      |
#  | BeamRemnants:halfScaleForKT                   |                  1.00000 |      1.50000         0.0             |
#  | BeamRemnants:primordialKThard                 |                  2.00000 |      1.80000         0.0             |
#  | BeamRemnants:primordialKTsoft                 |                  0.50000 |      0.90000         0.0             |
#  | Beams:eCM                                     |                 7000.000 |    14000.000         0.0             |
#  | Beams:idA                                     |                     2112 |         2212                         |
#  | ColourReconnection:range                      |                 10.00000 |      1.80000         0.0    10.00000 |
#  | Diffraction:largeMassSuppress                 |                  2.00000 |      4.00000         0.0             |
#  | HadronLevel:all                               |                      off |           on                         |
#  | HardQCD:all                                   |                       on |          off                         |
#  | MultipartonInteractions:alphaSvalue           |                  0.12700 |      0.13000   0.0600000     0.25000 |
#  | MultipartonInteractions:bProfile              |                        1 |            3           0           4 |
#  | MultipartonInteractions:ecmPow                |                  0.24000 |      0.21500         0.0     0.50000 |
#  | MultipartonInteractions:ecmRef                |                 1800.000 |     7000.000     1.00000             |
#  | MultipartonInteractions:expPow                |                  1.00000 |      1.85000     0.40000    10.00000 |
#  | MultipartonInteractions:pT0Ref                |                  2.25000 |      2.28000     0.50000    10.00000 |
#  | Next:numberCount                              |                        0 |         1000           0             |
#  | Next:numberShowEvent                          |                        0 |            1           0             |
#  | Next:numberShowInfo                           |                        0 |            1           0             |
#  | Next:numberShowLHA                            |                        0 |            1           0             |
#  | Next:numberShowProcess                        |                        0 |            1           0             |
#  | ParticleDecays:limitTau0                      |                       on |          off                         |
#  | PDF:pSet                                      |                        2 |           13                         |
#  | SigmaDiffractive:dampen                       |                      off |           on                         |
#  | SigmaProcess:alphaSvalue                      |                  0.12650 |      0.13000   0.0600000     0.25000 |
#  | SpaceShower:alphaSvalue                       |                  0.13700 |      0.13650   0.0600000     0.25000 |
#  | SpaceShower:ecmRef                            |                 1800.000 |     7000.000     1.00000             |
#  | SpaceShower:phiIntAsym                        |                      off |           on                         |
#  | SpaceShower:phiPolAsym                        |                      off |           on                         |
#  | SpaceShower:rapidityOrder                     |                      off |           on                         |
#  | SpaceShower:rapidityOrderMPI                  |                      off |           on                         |
#  | StringFlav:etaSup                             |                  0.63000 |      0.60000         0.0     1.00000 |
#  | StringFlav:mesonBvector                       |                  3.00000 |      2.20000         0.0     3.00000 |
#  | StringFlav:mesonCvector                       |                  1.06000 |      0.88000         0.0     3.00000 |
#  | StringFlav:mesonSvector                       |                  0.72500 |      0.55000         0.0     3.00000 |
#  | StringFlav:mesonUDvector                      |                  0.62000 |      0.50000         0.0     3.00000 |
#  | StringFlav:popcornSpair                       |                  0.50000 |      0.90000         0.0     1.00000 |
#  | StringFlav:probQQ1toQQ0                       |                0.0270000 |    0.0275000         0.0     1.00000 |
#  | StringFlav:probQQtoQ                          |                0.0900000 |    0.0810000         0.0     1.00000 |
#  | StringFlav:probSQtoQQ                         |                  1.00000 |      0.91500         0.0     1.00000 |
#  | StringFlav:probStoUD                          |                  0.19000 |      0.21700         0.0     1.00000 |
#  | StringPT:sigma                                |                  0.30400 |      0.33500         0.0     1.00000 |
#  | StringZ:aExtraDiquark                         |                  0.50000 |      0.97000         0.0     2.00000 |
#  | StringZ:aLund                                 |                  0.30000 |      0.68000         0.0     2.00000 |
#  | StringZ:bLund                                 |                  0.80000 |      0.98000     0.20000     2.00000 |
#  | StringZ:rFactB                                |                  0.67000 |      0.85500         0.0     2.00000 |
#  | StringZ:rFactC                                |                  1.00000 |      1.32000         0.0     2.00000 |
#  | TimeShower:alphaSvalue                        |                  0.13830 |      0.13650   0.0600000     0.25000 |
#  | TimeShower:dampenBeamRecoil                   |                      off |           on                         |
#  | TimeShower:phiPolAsym                         |                      off |           on                         |
#  | TimeShower:pTmin                              |                  0.40000 |      0.50000     0.10000     2.00000 |
#  | TimeShower:pTminChgQ                          |                  0.40000 |      0.50000     0.10000     2.00000 |
#  | Tune:ee                                       |                        3 |            7          -1           7 |
#  | Tune:pp                                       |                        2 |           14          -1          34 |
#  |                                                                                                                 |
#  *-------  End PYTHIA Flag + Mode + Parm + Word + FVec + MVec + PVec + WVec Settings  -----------------------------*
#
#  --------  PYTHIA Particle Data Table (changed only)  ------------------------------------------------------------------------------
#
#       id   name            antiName         spn chg col      m0        mWidth      mMin       mMax       tau0    res dec ext vis wid
#              no onMode   bRatio   meMode     products
#
#  no particle data has been changed from its default value
#
#  --------  End PYTHIA Particle Data Table  -----------------------------------------------------------------------------------------
#
# Generating a few signal events for signal process (np) to build up statistics
#  Angantyr Info: Initializing minimum bias processes.
#
#  *-------  PYTHIA Process Initialization  --------------------------*
#  |                                                                  |
#  | We collide p+ with p+ at a CM energy of 7.000e+03 GeV            |
#  |                                                                  |
#  |------------------------------------------------------------------|
#  |                                                    |             |
#  | Subprocess                                    Code |   Estimated |
#  |                                                    |    max (mb) |
#  |                                                    |             |
#  |------------------------------------------------------------------|
#  |                                                    |             |
#  | non-diffractive                                101 |   4.812e+01 |
#  | A B -> A B elastic                             102 |   1.970e+01 |
#  | A B -> X B single diffractive                  103 |   6.842e+00 |
#  | A B -> A X single diffractive                  104 |   6.842e+00 |
#  | A B -> X X double diffractive                  105 |   9.259e+00 |
#  | A B -> A X B central diffractive               106 |   0.000e+00 |
#  |                                                                  |
#  *-------  End PYTHIA Process Initialization -----------------------*
#
#  *-------  PYTHIA Multiparton Interactions Initialization  ---------*
#  |                                                                  |
#  |                   sigmaNonDiffractive =    48.12 mb              |
#  |                                                                  |
#  |    pT0 =  3.12 gives sigmaInteraction =   152.10 mb: accepted    |
#  |                                                                  |
#  *-------  End PYTHIA Multiparton Interactions Initialization  -----*
#
#  *-------  PYTHIA Multiparton Interactions Initialization  ---------*
#  |                                                                  |
#  |   diffraction XB for p+ on p+                                    |
#  |                                                                  |
#  |   diffractive mass = 1.00e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  0.65 gives sigmaInteraction =    12.45 mb: accepted    |
#  |   diffractive mass = 1.60e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  0.72 gives sigmaInteraction =    12.70 mb: accepted    |
#  |   diffractive mass = 2.55e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  0.81 gives sigmaInteraction =    12.51 mb: accepted    |
#  |   diffractive mass = 4.07e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  0.91 gives sigmaInteraction =    12.09 mb: accepted    |
#  |   diffractive mass = 6.50e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.01 gives sigmaInteraction =    11.59 mb: accepted    |
#  |   diffractive mass = 1.04e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.13 gives sigmaInteraction =    11.32 mb: accepted    |
#  |   diffractive mass = 1.66e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.27 gives sigmaInteraction =    11.35 mb: accepted    |
#  |   diffractive mass = 2.65e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.42 gives sigmaInteraction =    11.78 mb: accepted    |
#  |   diffractive mass = 4.22e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.59 gives sigmaInteraction =    12.62 mb: accepted    |
#  |   diffractive mass = 6.75e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.78 gives sigmaInteraction =    14.06 mb: accepted    |
#  |   diffractive mass = 1.08e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.99 gives sigmaInteraction =    15.80 mb: accepted    |
#  |   diffractive mass = 1.72e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  2.23 gives sigmaInteraction =    18.07 mb: accepted    |
#  |   diffractive mass = 2.75e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  2.49 gives sigmaInteraction =    20.76 mb: accepted    |
#  |   diffractive mass = 4.38e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  2.79 gives sigmaInteraction =    23.55 mb: accepted    |
#  |   diffractive mass = 7.00e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  3.12 gives sigmaInteraction =    27.78 mb: accepted    |
#  |                                                                  |
#  *-------  End PYTHIA Multiparton Interactions Initialization  -----*
#  PYTHIA Warning in MultipartonInteractions::init: maximum increased by factor 4.834
#
#  *-------  PYTHIA Multiparton Interactions Initialization  ---------*
#  |                                                                  |
#  |   diffraction AX for p+ on p+                                    |
#  |                                                                  |
#  |   diffractive mass = 1.00e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  0.65 gives sigmaInteraction =    12.36 mb: accepted    |
#  |   diffractive mass = 1.60e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  0.72 gives sigmaInteraction =    12.85 mb: accepted    |
#  |   diffractive mass = 2.55e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  0.81 gives sigmaInteraction =    12.51 mb: accepted    |
#  |   diffractive mass = 4.07e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  0.91 gives sigmaInteraction =    12.07 mb: accepted    |
#  |   diffractive mass = 6.50e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.01 gives sigmaInteraction =    11.58 mb: accepted    |
#  |   diffractive mass = 1.04e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.13 gives sigmaInteraction =    11.30 mb: accepted    |
#  |   diffractive mass = 1.66e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.27 gives sigmaInteraction =    11.41 mb: accepted    |
#  |   diffractive mass = 2.65e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.42 gives sigmaInteraction =    11.85 mb: accepted    |
#  |   diffractive mass = 4.22e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.59 gives sigmaInteraction =    12.74 mb: accepted    |
#  |   diffractive mass = 6.75e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.78 gives sigmaInteraction =    14.14 mb: accepted    |
#  |   diffractive mass = 1.08e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.99 gives sigmaInteraction =    15.93 mb: accepted    |
#  |   diffractive mass = 1.72e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  2.23 gives sigmaInteraction =    17.97 mb: accepted    |
#  |   diffractive mass = 2.75e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  2.49 gives sigmaInteraction =    20.71 mb: accepted    |
#  |   diffractive mass = 4.38e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  2.79 gives sigmaInteraction =    23.82 mb: accepted    |
#  |   diffractive mass = 7.00e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  3.12 gives sigmaInteraction =    27.55 mb: accepted    |
#  |                                                                  |
#  *-------  End PYTHIA Multiparton Interactions Initialization  -----*
#
#  *-------  PYTHIA Multiparton Interactions Initialization  ---------*
#  |                                                                  |
#  |   diffraction AXB for p+ on p+                                   |
#  |                                                                  |
#  |   diffractive mass = 1.00e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  0.65 gives sigmaInteraction =     2.74 mb: rejected    |
#  |    pT0 =  0.58 gives sigmaInteraction =     4.02 mb: rejected    |
#  |    pT0 =  0.52 gives sigmaInteraction =     5.85 mb: rejected    |
#  |    pT0 =  0.47 gives sigmaInteraction =     8.54 mb: rejected    |
#  |    pT0 =  0.42 gives sigmaInteraction =    12.35 mb: accepted    |
#  |   diffractive mass = 1.60e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  0.72 gives sigmaInteraction =     2.27 mb: rejected    |
#  |    pT0 =  0.65 gives sigmaInteraction =     3.24 mb: rejected    |
#  |    pT0 =  0.59 gives sigmaInteraction =     4.63 mb: rejected    |
#  |    pT0 =  0.53 gives sigmaInteraction =     6.68 mb: rejected    |
#  |    pT0 =  0.47 gives sigmaInteraction =     9.62 mb: rejected    |
#  |    pT0 =  0.43 gives sigmaInteraction =    13.92 mb: accepted    |
#  |   diffractive mass = 2.55e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  0.81 gives sigmaInteraction =     1.85 mb: rejected    |
#  |    pT0 =  0.73 gives sigmaInteraction =     2.59 mb: rejected    |
#  |    pT0 =  0.66 gives sigmaInteraction =     3.66 mb: rejected    |
#  |    pT0 =  0.59 gives sigmaInteraction =     5.16 mb: rejected    |
#  |    pT0 =  0.53 gives sigmaInteraction =     7.27 mb: rejected    |
#  |    pT0 =  0.48 gives sigmaInteraction =    10.30 mb: rejected    |
#  |    pT0 =  0.43 gives sigmaInteraction =    14.64 mb: accepted    |
#  |   diffractive mass = 4.07e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  0.91 gives sigmaInteraction =     1.58 mb: rejected    |
#  |    pT0 =  0.82 gives sigmaInteraction =     2.14 mb: rejected    |
#  |    pT0 =  0.73 gives sigmaInteraction =     2.92 mb: rejected    |
#  |    pT0 =  0.66 gives sigmaInteraction =     4.01 mb: rejected    |
#  |    pT0 =  0.59 gives sigmaInteraction =     5.54 mb: rejected    |
#  |    pT0 =  0.54 gives sigmaInteraction =     7.68 mb: rejected    |
#  |    pT0 =  0.48 gives sigmaInteraction =    10.84 mb: rejected    |
#  |    pT0 =  0.43 gives sigmaInteraction =    15.29 mb: accepted    |
#  |   diffractive mass = 6.50e+01 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.01 gives sigmaInteraction =     1.41 mb: rejected    |
#  |    pT0 =  0.91 gives sigmaInteraction =     1.84 mb: rejected    |
#  |    pT0 =  0.82 gives sigmaInteraction =     2.44 mb: rejected    |
#  |    pT0 =  0.74 gives sigmaInteraction =     3.24 mb: rejected    |
#  |    pT0 =  0.67 gives sigmaInteraction =     4.42 mb: rejected    |
#  |    pT0 =  0.60 gives sigmaInteraction =     5.88 mb: rejected    |
#  |    pT0 =  0.54 gives sigmaInteraction =     8.13 mb: rejected    |
#  |    pT0 =  0.48 gives sigmaInteraction =    11.26 mb: accepted    |
#  |   diffractive mass = 1.04e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.13 gives sigmaInteraction =     1.37 mb: rejected    |
#  |    pT0 =  1.02 gives sigmaInteraction =     1.75 mb: rejected    |
#  |    pT0 =  0.92 gives sigmaInteraction =     2.21 mb: rejected    |
#  |    pT0 =  0.83 gives sigmaInteraction =     2.84 mb: rejected    |
#  |    pT0 =  0.74 gives sigmaInteraction =     3.69 mb: rejected    |
#  |    pT0 =  0.67 gives sigmaInteraction =     4.79 mb: rejected    |
#  |    pT0 =  0.60 gives sigmaInteraction =     6.31 mb: rejected    |
#  |    pT0 =  0.54 gives sigmaInteraction =     8.63 mb: rejected    |
#  |    pT0 =  0.49 gives sigmaInteraction =    11.59 mb: accepted    |
#  |   diffractive mass = 1.66e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.27 gives sigmaInteraction =     1.44 mb: rejected    |
#  |    pT0 =  1.14 gives sigmaInteraction =     1.76 mb: rejected    |
#  |    pT0 =  1.03 gives sigmaInteraction =     2.17 mb: rejected    |
#  |    pT0 =  0.93 gives sigmaInteraction =     2.72 mb: rejected    |
#  |    pT0 =  0.83 gives sigmaInteraction =     3.38 mb: rejected    |
#  |    pT0 =  0.75 gives sigmaInteraction =     4.25 mb: rejected    |
#  |    pT0 =  0.67 gives sigmaInteraction =     5.42 mb: rejected    |
#  |    pT0 =  0.61 gives sigmaInteraction =     6.96 mb: rejected    |
#  |    pT0 =  0.55 gives sigmaInteraction =     9.16 mb: rejected    |
#  |    pT0 =  0.49 gives sigmaInteraction =    12.14 mb: accepted    |
#  |   diffractive mass = 2.65e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.42 gives sigmaInteraction =     1.59 mb: rejected    |
#  |    pT0 =  1.28 gives sigmaInteraction =     1.92 mb: rejected    |
#  |    pT0 =  1.15 gives sigmaInteraction =     2.30 mb: rejected    |
#  |    pT0 =  1.04 gives sigmaInteraction =     2.78 mb: rejected    |
#  |    pT0 =  0.93 gives sigmaInteraction =     3.35 mb: rejected    |
#  |    pT0 =  0.84 gives sigmaInteraction =     4.05 mb: rejected    |
#  |    pT0 =  0.75 gives sigmaInteraction =     5.01 mb: rejected    |
#  |    pT0 =  0.68 gives sigmaInteraction =     6.13 mb: rejected    |
#  |    pT0 =  0.61 gives sigmaInteraction =     7.73 mb: rejected    |
#  |    pT0 =  0.55 gives sigmaInteraction =     9.89 mb: rejected    |
#  |    pT0 =  0.50 gives sigmaInteraction =    12.89 mb: accepted    |
#  |   diffractive mass = 4.22e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.59 gives sigmaInteraction =     1.78 mb: rejected    |
#  |    pT0 =  1.43 gives sigmaInteraction =     2.13 mb: rejected    |
#  |    pT0 =  1.29 gives sigmaInteraction =     2.57 mb: rejected    |
#  |    pT0 =  1.16 gives sigmaInteraction =     3.03 mb: rejected    |
#  |    pT0 =  1.04 gives sigmaInteraction =     3.57 mb: rejected    |
#  |    pT0 =  0.94 gives sigmaInteraction =     4.21 mb: rejected    |
#  |    pT0 =  0.84 gives sigmaInteraction =     5.00 mb: rejected    |
#  |    pT0 =  0.76 gives sigmaInteraction =     5.98 mb: rejected    |
#  |    pT0 =  0.68 gives sigmaInteraction =     7.15 mb: rejected    |
#  |    pT0 =  0.62 gives sigmaInteraction =     8.95 mb: rejected    |
#  |    pT0 =  0.55 gives sigmaInteraction =    11.02 mb: accepted    |
#  |   diffractive mass = 6.75e+02 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.78 gives sigmaInteraction =     2.05 mb: rejected    |
#  |    pT0 =  1.60 gives sigmaInteraction =     2.44 mb: rejected    |
#  |    pT0 =  1.44 gives sigmaInteraction =     2.89 mb: rejected    |
#  |    pT0 =  1.30 gives sigmaInteraction =     3.36 mb: rejected    |
#  |    pT0 =  1.17 gives sigmaInteraction =     3.97 mb: rejected    |
#  |    pT0 =  1.05 gives sigmaInteraction =     4.58 mb: rejected    |
#  |    pT0 =  0.94 gives sigmaInteraction =     5.32 mb: rejected    |
#  |    pT0 =  0.85 gives sigmaInteraction =     6.23 mb: rejected    |
#  |    pT0 =  0.77 gives sigmaInteraction =     7.24 mb: rejected    |
#  |    pT0 =  0.69 gives sigmaInteraction =     8.48 mb: rejected    |
#  |    pT0 =  0.62 gives sigmaInteraction =    10.27 mb: rejected    |
#  |    pT0 =  0.56 gives sigmaInteraction =    12.39 mb: accepted    |
#  |   diffractive mass = 1.08e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  1.99 gives sigmaInteraction =     2.31 mb: rejected    |
#  |    pT0 =  1.79 gives sigmaInteraction =     2.77 mb: rejected    |
#  |    pT0 =  1.61 gives sigmaInteraction =     3.26 mb: rejected    |
#  |    pT0 =  1.45 gives sigmaInteraction =     3.82 mb: rejected    |
#  |    pT0 =  1.31 gives sigmaInteraction =     4.42 mb: rejected    |
#  |    pT0 =  1.17 gives sigmaInteraction =     5.15 mb: rejected    |
#  |    pT0 =  1.06 gives sigmaInteraction =     5.91 mb: rejected    |
#  |    pT0 =  0.95 gives sigmaInteraction =     6.72 mb: rejected    |
#  |    pT0 =  0.86 gives sigmaInteraction =     7.81 mb: rejected    |
#  |    pT0 =  0.77 gives sigmaInteraction =     8.79 mb: rejected    |
#  |    pT0 =  0.69 gives sigmaInteraction =    10.12 mb: rejected    |
#  |    pT0 =  0.62 gives sigmaInteraction =    11.91 mb: accepted    |
#  |   diffractive mass = 1.72e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  2.23 gives sigmaInteraction =     2.62 mb: rejected    |
#  |    pT0 =  2.00 gives sigmaInteraction =     3.14 mb: rejected    |
#  |    pT0 =  1.80 gives sigmaInteraction =     3.71 mb: rejected    |
#  |    pT0 =  1.62 gives sigmaInteraction =     4.34 mb: rejected    |
#  |    pT0 =  1.46 gives sigmaInteraction =     5.03 mb: rejected    |
#  |    pT0 =  1.31 gives sigmaInteraction =     5.77 mb: rejected    |
#  |    pT0 =  1.18 gives sigmaInteraction =     6.63 mb: rejected    |
#  |    pT0 =  1.06 gives sigmaInteraction =     7.47 mb: rejected    |
#  |    pT0 =  0.96 gives sigmaInteraction =     8.51 mb: rejected    |
#  |    pT0 =  0.86 gives sigmaInteraction =     9.61 mb: rejected    |
#  |    pT0 =  0.78 gives sigmaInteraction =    10.69 mb: rejected    |
#  |    pT0 =  0.70 gives sigmaInteraction =    12.20 mb: accepted    |
#  |   diffractive mass = 2.75e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  2.49 gives sigmaInteraction =     2.90 mb: rejected    |
#  |    pT0 =  2.24 gives sigmaInteraction =     3.48 mb: rejected    |
#  |    pT0 =  2.02 gives sigmaInteraction =     4.12 mb: rejected    |
#  |    pT0 =  1.82 gives sigmaInteraction =     4.84 mb: rejected    |
#  |    pT0 =  1.63 gives sigmaInteraction =     5.65 mb: rejected    |
#  |    pT0 =  1.47 gives sigmaInteraction =     6.47 mb: rejected    |
#  |    pT0 =  1.32 gives sigmaInteraction =     7.42 mb: rejected    |
#  |    pT0 =  1.19 gives sigmaInteraction =     8.46 mb: rejected    |
#  |    pT0 =  1.07 gives sigmaInteraction =     9.48 mb: rejected    |
#  |    pT0 =  0.96 gives sigmaInteraction =    10.54 mb: rejected    |
#  |    pT0 =  0.87 gives sigmaInteraction =    11.84 mb: accepted    |
#  |   diffractive mass = 4.38e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  2.79 gives sigmaInteraction =     3.20 mb: rejected    |
#  |    pT0 =  2.51 gives sigmaInteraction =     3.91 mb: rejected    |
#  |    pT0 =  2.26 gives sigmaInteraction =     4.62 mb: rejected    |
#  |    pT0 =  2.03 gives sigmaInteraction =     5.35 mb: rejected    |
#  |    pT0 =  1.83 gives sigmaInteraction =     6.30 mb: rejected    |
#  |    pT0 =  1.65 gives sigmaInteraction =     7.30 mb: rejected    |
#  |    pT0 =  1.48 gives sigmaInteraction =     8.26 mb: rejected    |
#  |    pT0 =  1.33 gives sigmaInteraction =     9.33 mb: rejected    |
#  |    pT0 =  1.20 gives sigmaInteraction =    10.59 mb: rejected    |
#  |    pT0 =  1.08 gives sigmaInteraction =    11.81 mb: accepted    |
#  |   diffractive mass = 7.00e+03 GeV and sigmaNorm =    10.00 mb    |
#  |    pT0 =  3.12 gives sigmaInteraction =     3.50 mb: rejected    |
#  |    pT0 =  2.81 gives sigmaInteraction =     4.21 mb: rejected    |
#  |    pT0 =  2.52 gives sigmaInteraction =     4.95 mb: rejected    |
#  |    pT0 =  2.27 gives sigmaInteraction =     5.93 mb: rejected    |
#  |    pT0 =  2.05 gives sigmaInteraction =     6.93 mb: rejected    |
#  |    pT0 =  1.84 gives sigmaInteraction =     7.96 mb: rejected    |
#  |    pT0 =  1.66 gives sigmaInteraction =     9.13 mb: rejected    |
#  |    pT0 =  1.49 gives sigmaInteraction =    10.52 mb: rejected    |
#  |    pT0 =  1.34 gives sigmaInteraction =    11.79 mb: accepted    |
#  |                                                                  |
#  *-------  End PYTHIA Multiparton Interactions Initialization  -----*
#
#  *-------  PYTHIA Flag + Mode + Parm + Word + FVec + MVec + PVec + WVec Settings (changes only)  ------------------*
#  |                                                                                                                 |
#  | Name                                          |                      Now |      Default         Min         Max |
#  |                                               |                          |                                      |
#  | BeamRemnants:halfScaleForKT                   |                  1.00000 |      1.50000         0.0             |
#  | BeamRemnants:primordialKThard                 |                  2.00000 |      1.80000         0.0             |
#  | BeamRemnants:primordialKTsoft                 |                  0.50000 |      0.90000         0.0             |
#  | Beams:eCM                                     |                 7000.000 |    14000.000         0.0             |
#  | ColourReconnection:range                      |                 10.00000 |      1.80000         0.0    10.00000 |
#  | Diffraction:largeMassSuppress                 |                  2.00000 |      4.00000         0.0             |
#  | HadronLevel:all                               |                      off |           on                         |
#  | MultipartonInteractions:alphaSvalue           |                  0.12700 |      0.13000   0.0600000     0.25000 |
#  | MultipartonInteractions:bProfile              |                        1 |            3           0           4 |
#  | MultipartonInteractions:ecmPow                |                  0.24000 |      0.21500         0.0     0.50000 |
#  | MultipartonInteractions:ecmRef                |                 1800.000 |     7000.000     1.00000             |
#  | MultipartonInteractions:expPow                |                  1.00000 |      1.85000     0.40000    10.00000 |
#  | MultipartonInteractions:pT0Ref                |                  2.25000 |      2.28000     0.50000    10.00000 |
#  | Next:numberCount                              |                        0 |         1000           0             |
#  | Next:numberShowEvent                          |                        0 |            1           0             |
#  | Next:numberShowInfo                           |                        0 |            1           0             |
#  | Next:numberShowLHA                            |                        0 |            1           0             |
#  | Next:numberShowProcess                        |                        0 |            1           0             |
#  | ParticleDecays:limitTau0                      |                       on |          off                         |
#  | PDF:pSet                                      |                        2 |           13                         |
#  | SigmaDiffractive:dampen                       |                      off |           on                         |
#  | SigmaProcess:alphaSvalue                      |                  0.12650 |      0.13000   0.0600000     0.25000 |
#  | SoftQCD:all                                   |                       on |          off                         |
#  | SpaceShower:alphaSvalue                       |                  0.13700 |      0.13650   0.0600000     0.25000 |
#  | SpaceShower:ecmRef                            |                 1800.000 |     7000.000     1.00000             |
#  | SpaceShower:phiIntAsym                        |                      off |           on                         |
#  | SpaceShower:phiPolAsym                        |                      off |           on                         |
# ...
#  |    pT0 =  2.05 gives sigmaInteraction =    57.23 mb: accepted    |
#  |   diffractive mass = 6.50e+01 GeV and sigmaNorm =    48.12 mb    |
#  |    pT0 =  2.28 gives sigmaInteraction =    51.67 mb: rejected    |
#  |    pT0 =  2.05 gives sigmaInteraction =    72.43 mb: accepted    |
#  |   diffractive mass = 1.04e+02 GeV and sigmaNorm =    48.12 mb    |
#  |    pT0 =  2.28 gives sigmaInteraction =    67.56 mb: accepted    |
#  |   diffractive mass = 1.66e+02 GeV and sigmaNorm =    48.12 mb    |
#  |    pT0 =  2.28 gives sigmaInteraction =    85.55 mb: accepted    |
#  |   diffractive mass = 2.65e+02 GeV and sigmaNorm =    48.12 mb    |
#  |    pT0 =  2.28 gives sigmaInteraction =   106.69 mb: accepted    |
#  |   diffractive mass = 4.22e+02 GeV and sigmaNorm =    48.12 mb    |
#  |    pT0 =  2.28 gives sigmaInteraction =   128.78 mb: accepted    |
#  |   diffractive mass = 6.75e+02 GeV and sigmaNorm =    48.12 mb    |
#  |    pT0 =  2.28 gives sigmaInteraction =   153.46 mb: accepted    |
#  |   diffractive mass = 1.08e+03 GeV and sigmaNorm =    48.12 mb    |
#  |    pT0 =  2.28 gives sigmaInteraction =   174.76 mb: accepted    |
#  |   diffractive mass = 1.72e+03 GeV and sigmaNorm =    48.12 mb    |
#  |    pT0 =  2.28 gives sigmaInteraction =   196.48 mb: accepted    |
#  |   diffractive mass = 2.75e+03 GeV and sigmaNorm =    48.12 mb    |
#  |    pT0 =  2.28 gives sigmaInteraction =   211.55 mb: accepted    |
#  |   diffractive mass = 4.38e+03 GeV and sigmaNorm =    48.12 mb    |
#  |    pT0 =  2.28 gives sigmaInteraction =   225.27 mb: accepted    |
#  |   diffractive mass = 7.00e+03 GeV and sigmaNorm =    48.12 mb    |
#  |    pT0 =  2.28 gives sigmaInteraction =   226.09 mb: accepted    |
#  |                                                                  |
#  *-------  End PYTHIA Multiparton Interactions Initialization  -----*
#
#  *-------  PYTHIA Flag + Mode + Parm + Word + FVec + MVec + PVec + WVec Settings (changes only)  ------------------*
#  |                                                                                                                 |
#  | Name                                          |                      Now |      Default         Min         Max |
#  |                                               |                          |                                      |
#  | Beams:eCM                                     |                 7000.000 |    14000.000         0.0             |
#  | ColourReconnection:range                      |                 10.00000 |      1.80000         0.0    10.00000 |
#  | Diffraction:mRefPomP                          |                 7000.000 |    100.00000     1.00000             |
#  | Diffraction:sigmaRefPomP                      |                 48.12128 |     10.00000     2.00000    40.00000 |
#  | HadronLevel:all                               |                      off |           on                         |
#  | MultipartonInteractions:ecmPow                |                      0.0 |      0.21500         0.0     0.50000 |
#  | Next:numberCount                              |                        0 |         1000           0             |
#  | Next:numberShowEvent                          |                        0 |            1           0             |
#  | Next:numberShowInfo                           |                        0 |            1           0             |
#  | Next:numberShowLHA                            |                        0 |            1           0             |
#  | Next:numberShowProcess                        |                        0 |            1           0             |
#  | ParticleDecays:limitTau0                      |                       on |          off                         |
#  | PDF:PomSet                                    |                       11 |            6                         |
#  | SigmaProcess:alphaSvalue                      |                  0.12650 |      0.13000   0.0600000     0.25000 |
#  | SoftQCD:singleDiffractive                     |                       on |          off                         |
#  | SpaceShower:alphaSvalue                       |                  0.13700 |      0.13650   0.0600000     0.25000 |
#  | SpaceShower:ecmRef                            |                 1800.000 |     7000.000     1.00000             |
#  | SpaceShower:phiIntAsym                        |                      off |           on                         |
#  | SpaceShower:phiPolAsym                        |                      off |           on                         |
#  | SpaceShower:rapidityOrder                     |                      off |           on                         |
#  | SpaceShower:rapidityOrderMPI                  |                      off |           on                         |
#  | StringFlav:etaSup                             |                  0.63000 |      0.60000         0.0     1.00000 |
#  | StringFlav:mesonBvector                       |                  3.00000 |      2.20000         0.0     3.00000 |
#  | StringFlav:mesonCvector                       |                  1.06000 |      0.88000         0.0     3.00000 |
#  | StringFlav:mesonSvector                       |                  0.72500 |      0.55000         0.0     3.00000 |
#  | StringFlav:mesonUDvector                      |                  0.62000 |      0.50000         0.0     3.00000 |
#  | StringFlav:popcornSpair                       |                  0.50000 |      0.90000         0.0     1.00000 |
#  | StringFlav:probQQ1toQQ0                       |                0.0270000 |    0.0275000         0.0     1.00000 |
#  | StringFlav:probQQtoQ                          |                0.0900000 |    0.0810000         0.0     1.00000 |
#  | StringFlav:probSQtoQQ                         |                  1.00000 |      0.91500         0.0     1.00000 |
#  | StringFlav:probStoUD                          |                  0.19000 |      0.21700         0.0     1.00000 |
#  | StringPT:sigma                                |                  0.30400 |      0.33500         0.0     1.00000 |
#  | StringZ:aExtraDiquark                         |                  0.50000 |      0.97000         0.0     2.00000 |
#  | StringZ:aLund                                 |                  0.30000 |      0.68000         0.0     2.00000 |
#  | StringZ:bLund                                 |                  0.80000 |      0.98000     0.20000     2.00000 |
#  | StringZ:rFactB                                |                  0.67000 |      0.85500         0.0     2.00000 |
#  | StringZ:rFactC                                |                  1.00000 |      1.32000         0.0     2.00000 |
#  | TimeShower:alphaSvalue                        |                  0.13830 |      0.13650   0.0600000     0.25000 |
#  | TimeShower:dampenBeamRecoil                   |                      off |           on                         |
#  | TimeShower:phiPolAsym                         |                      off |           on                         |
#  | TimeShower:pTmin                              |                  0.40000 |      0.50000     0.10000     2.00000 |
#  | TimeShower:pTminChgQ                          |                  0.40000 |      0.50000     0.10000     2.00000 |
#  | Tune:ee                                       |                        0 |            7          -1           7 |
#  | Tune:pp                                       |                        0 |           14          -1          34 |
#  |                                                                                                                 |
#  *-------  End PYTHIA Flag + Mode + Parm + Word + FVec + MVec + PVec + WVec Settings  -----------------------------*
#
#  --------  PYTHIA Particle Data Table (changed only)  ------------------------------------------------------------------------------
#
#       id   name            antiName         spn chg col      m0        mWidth      mMin       mMax       tau0    res dec ext vis wid
#              no onMode   bRatio   meMode     products
#
#  no particle data has been changed from its default value
#
#  --------  End PYTHIA Particle Data Table  -----------------------------------------------------------------------------------------
#
#  Angantyr Info: Initializing hadronisation processes.
#
#  *-------  PYTHIA Flag + Mode + Parm + Word + FVec + MVec + PVec + WVec Settings (changes only)  ------------------*
#  |                                                                                                                 |
#  | Name                                          |                      Now |      Default         Min         Max |
#  |                                               |                          |                                      |
#  | BeamRemnants:halfScaleForKT                   |                  1.00000 |      1.50000         0.0             |
#  | BeamRemnants:primordialKThard                 |                  2.00000 |      1.80000         0.0             |
#  | BeamRemnants:primordialKTsoft                 |                  0.50000 |      0.90000         0.0             |
#  | Beams:eCM                                     |                 7000.000 |    14000.000         0.0             |
#  | Beams:idA                                     |               1000822080 |         2212                         |
#  | ColourReconnection:range                      |                 10.00000 |      1.80000         0.0    10.00000 |
#  | Diffraction:largeMassSuppress                 |                  2.00000 |      4.00000         0.0             |
#  | MultipartonInteractions:alphaSvalue           |                  0.12700 |      0.13000   0.0600000     0.25000 |
#  | MultipartonInteractions:bProfile              |                        1 |            3           0           4 |
#  | MultipartonInteractions:ecmPow                |                  0.24000 |      0.21500         0.0     0.50000 |
#  | MultipartonInteractions:ecmRef                |                 1800.000 |     7000.000     1.00000             |
#  | MultipartonInteractions:expPow                |                  1.00000 |      1.85000     0.40000    10.00000 |
#  | MultipartonInteractions:pT0Ref                |                  2.25000 |      2.28000     0.50000    10.00000 |
#  | Next:numberCount                              |                        0 |         1000           0             |
#  | Next:numberShowEvent                          |                        0 |            1           0             |
#  | Next:numberShowInfo                           |                        0 |            1           0             |
#  | Next:numberShowLHA                            |                        0 |            1           0             |
#  | Next:numberShowProcess                        |                        0 |            1           0             |
#  | ParticleDecays:limitTau0                      |                       on |          off                         |
#  | PartonLevel:all                               |                      off |           on                         |
#  | PDF:pSet                                      |                        2 |           13                         |
#  | ProcessLevel:all                              |                      off |           on                         |
#  | SigmaDiffractive:dampen                       |                      off |           on                         |
#  | SigmaProcess:alphaSvalue                      |                  0.12650 |      0.13000   0.0600000     0.25000 |
#  | SpaceShower:alphaSvalue                       |                  0.13700 |      0.13650   0.0600000     0.25000 |
#  | SpaceShower:ecmRef                            |                 1800.000 |     7000.000     1.00000             |
#  | SpaceShower:phiIntAsym                        |                      off |           on                         |
#  | SpaceShower:phiPolAsym                        |                      off |           on                         |
#  | SpaceShower:rapidityOrder                     |                      off |           on                         |
#  | SpaceShower:rapidityOrderMPI                  |                      off |           on                         |
#  | StringFlav:etaSup                             |                  0.63000 |      0.60000         0.0     1.00000 |
#  | StringFlav:mesonBvector                       |                  3.00000 |      2.20000         0.0     3.00000 |
#  | StringFlav:mesonCvector                       |                  1.06000 |      0.88000         0.0     3.00000 |
#  | StringFlav:mesonSvector                       |                  0.72500 |      0.55000         0.0     3.00000 |
#  | StringFlav:mesonUDvector                      |                  0.62000 |      0.50000         0.0     3.00000 |
#  | StringFlav:popcornSpair                       |                  0.50000 |      0.90000         0.0     1.00000 |
#  | StringFlav:probQQ1toQQ0                       |                0.0270000 |    0.0275000         0.0     1.00000 |
#  | StringFlav:probQQtoQ                          |                0.0900000 |    0.0810000         0.0     1.00000 |
#  | StringFlav:probSQtoQQ                         |                  1.00000 |      0.91500         0.0     1.00000 |
#  | StringFlav:probStoUD                          |                  0.19000 |      0.21700         0.0     1.00000 |
#  | StringPT:sigma                                |                  0.30400 |      0.33500         0.0     1.00000 |
#  | StringZ:aExtraDiquark                         |                  0.50000 |      0.97000         0.0     2.00000 |
#  | StringZ:aLund                                 |                  0.30000 |      0.68000         0.0     2.00000 |
#  | StringZ:bLund                                 |                  0.80000 |      0.98000     0.20000     2.00000 |
#  | StringZ:rFactB                                |                  0.67000 |      0.85500         0.0     2.00000 |
#  | StringZ:rFactC                                |                  1.00000 |      1.32000         0.0     2.00000 |
#  | TimeShower:alphaSvalue                        |                  0.13830 |      0.13650   0.0600000     0.25000 |
#  | TimeShower:dampenBeamRecoil                   |                      off |           on                         |
#  | TimeShower:phiPolAsym                         |                      off |           on                         |
#  | TimeShower:pTmin                              |                  0.40000 |      0.50000     0.10000     2.00000 |
#  | TimeShower:pTminChgQ                          |                  0.40000 |      0.50000     0.10000     2.00000 |
#  | Tune:ee                                       |                        0 |            7          -1           7 |
#  | Tune:pp                                       |                        0 |           14          -1          34 |
#  |                                                                                                                 |
#  *-------  End PYTHIA Flag + Mode + Parm + Word + FVec + MVec + PVec + WVec Settings  -----------------------------*
#
#  --------  PYTHIA Particle Data Table (changed only)  ------------------------------------------------------------------------------
#
#       id   name            antiName         spn chg col      m0        mWidth      mMin       mMax       tau0    res dec ext vis wid
#              no onMode   bRatio   meMode     products
#
#  no particle data has been changed from its default value
#
#  --------  End PYTHIA Particle Data Table  -----------------------------------------------------------------------------------------
#
#  PYTHIA Error in BeamRemnants::setKinematics: kinematics construction failed after retrying 10 times
#  PYTHIA Warning in SimpleSpaceShower::pT2nextQCD: weight above unity
